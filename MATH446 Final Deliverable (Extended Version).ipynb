# %% [markdown]
# Math446 Final Project | Fall 2021 <br>
# Nick Labruna, Yixiao Li, Dario Offstein, Samantha Zhang

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span><ul class="toc-item"><li><span><a href="#Data-Dictionary" data-toc-modified-id="Data-Dictionary-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Data Dictionary</a></span></li><li><span><a href="#Additional-Notes" data-toc-modified-id="Additional-Notes-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Additional Notes</a></span></li><li><span><a href="#Imports" data-toc-modified-id="Imports-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Imports</a></span></li></ul></li><li><span><a href="#Uniswap-Data:-Exploratory-Analysis" data-toc-modified-id="Uniswap-Data:-Exploratory-Analysis-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Uniswap Data: Exploratory Analysis</a></span><ul class="toc-item"><li><span><a href="#Create-dataset-with-only-transactions-in-DAI-ETH-pool" data-toc-modified-id="Create-dataset-with-only-transactions-in-DAI-ETH-pool-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Create dataset with only transactions in DAI-ETH pool</a></span></li><li><span><a href="#More-work-with-combined-Uniswap-dataset" data-toc-modified-id="More-work-with-combined-Uniswap-dataset-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>More work with combined Uniswap dataset</a></span><ul class="toc-item"><li><span><a href="#Time-series-of-DAI-and-ETH-in-pool" data-toc-modified-id="Time-series-of-DAI-and-ETH-in-pool-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Time series of DAI and ETH in pool</a></span></li></ul></li><li><span><a href="#Find-how-much-DAI-and-ETH-each-wallet-in-the-pool-owns" data-toc-modified-id="Find-how-much-DAI-and-ETH-each-wallet-in-the-pool-owns-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Find how much DAI and ETH each wallet in the pool owns</a></span></li><li><span><a href="#Simplify-actions-dataset" data-toc-modified-id="Simplify-actions-dataset-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Simplify actions dataset</a></span></li></ul></li><li><span><a href="#SushiSwap-Data:-Initialization" data-toc-modified-id="SushiSwap-Data:-Initialization-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>SushiSwap Data: Initialization</a></span><ul class="toc-item"><li><ul class="toc-item"><li><span><a href="#Mints" data-toc-modified-id="Mints-3.0.1"><span class="toc-item-num">3.0.1&nbsp;&nbsp;</span>Mints</a></span></li><li><span><a href="#Burns" data-toc-modified-id="Burns-3.0.2"><span class="toc-item-num">3.0.2&nbsp;&nbsp;</span>Burns</a></span></li><li><span><a href="#Swaps" data-toc-modified-id="Swaps-3.0.3"><span class="toc-item-num">3.0.3&nbsp;&nbsp;</span>Swaps</a></span></li><li><span><a href="#Concatenate-Burns,-Mints,-and-Swaps-into-one-large-dataframe" data-toc-modified-id="Concatenate-Burns,-Mints,-and-Swaps-into-one-large-dataframe-3.0.4"><span class="toc-item-num">3.0.4&nbsp;&nbsp;</span>Concatenate Burns, Mints, and Swaps into one large dataframe</a></span></li><li><span><a href="#Convert-datatypes" data-toc-modified-id="Convert-datatypes-3.0.5"><span class="toc-item-num">3.0.5&nbsp;&nbsp;</span>Convert datatypes</a></span></li></ul></li></ul></li><li><span><a href="#Sushiswap-Wallet-Address-Analysis" data-toc-modified-id="Sushiswap-Wallet-Address-Analysis-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Sushiswap Wallet Address Analysis</a></span></li><li><span><a href="#Calculate-Inputs-for-Impermanent-Loss" data-toc-modified-id="Calculate-Inputs-for-Impermanent-Loss-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Calculate Inputs for Impermanent Loss</a></span><ul class="toc-item"><li><span><a href="#Cumulative-Sum" data-toc-modified-id="Cumulative-Sum-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Cumulative Sum</a></span><ul class="toc-item"><li><span><a href="#USDC" data-toc-modified-id="USDC-5.1.1"><span class="toc-item-num">5.1.1&nbsp;&nbsp;</span>USDC</a></span></li><li><span><a href="#ETH" data-toc-modified-id="ETH-5.1.2"><span class="toc-item-num">5.1.2&nbsp;&nbsp;</span>ETH</a></span></li></ul></li><li><span><a href="#ETH-Rate" data-toc-modified-id="ETH-Rate-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>ETH Rate</a></span></li><li><span><a href="#Personal-Percent-Ownership" data-toc-modified-id="Personal-Percent-Ownership-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Personal Percent Ownership</a></span></li></ul></li><li><span><a href="#Impermanent-Loss-Approach-1:-Calculating-IL-for-each-Wallet-Address" data-toc-modified-id="Impermanent-Loss-Approach-1:-Calculating-IL-for-each-Wallet-Address-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Impermanent Loss Approach 1: Calculating IL for each Wallet Address</a></span><ul class="toc-item"><li><span><a href="#Initialize-Impermanent-loss-functions" data-toc-modified-id="Initialize-Impermanent-loss-functions-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Initialize Impermanent loss functions</a></span><ul class="toc-item"><li><span><a href="#Calculation-for-personal_perc" data-toc-modified-id="Calculation-for-personal_perc-6.1.1"><span class="toc-item-num">6.1.1&nbsp;&nbsp;</span>Calculation for <code>personal_perc</code></a></span></li><li><span><a href="#Calculation-for-impermanent_loss" data-toc-modified-id="Calculation-for-impermanent_loss-6.1.2"><span class="toc-item-num">6.1.2&nbsp;&nbsp;</span>Calculation for <code>impermanent_loss</code></a></span></li></ul></li><li><span><a href="#Create-separate-dataframes-for-each-wallet" data-toc-modified-id="Create-separate-dataframes-for-each-wallet-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Create separate dataframes for each wallet</a></span><ul class="toc-item"><li><span><a href="#Wallet-1" data-toc-modified-id="Wallet-1-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Wallet 1</a></span></li><li><span><a href="#Wallet-2" data-toc-modified-id="Wallet-2-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Wallet 2</a></span></li><li><span><a href="#Wallet-3" data-toc-modified-id="Wallet-3-6.2.3"><span class="toc-item-num">6.2.3&nbsp;&nbsp;</span>Wallet 3</a></span></li></ul></li></ul></li><li><span><a href="#Impermanent-Loss-Approach-2:-Net-Value-vs.-Holding" data-toc-modified-id="Impermanent-Loss-Approach-2:-Net-Value-vs.-Holding-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>Impermanent Loss Approach 2: Net Value vs. Holding</a></span><ul class="toc-item"><li><span><a href="#Isolate-data-to-only-wallet-addresses-with-1-burn,-1-mint" data-toc-modified-id="Isolate-data-to-only-wallet-addresses-with-1-burn,-1-mint-7.1"><span class="toc-item-num">7.1&nbsp;&nbsp;</span>Isolate data to only wallet addresses with 1 burn, 1 mint</a></span></li><li><span><a href="#Gather-all-data-for-wallets-of-interest" data-toc-modified-id="Gather-all-data-for-wallets-of-interest-7.2"><span class="toc-item-num">7.2&nbsp;&nbsp;</span>Gather all data for wallets of interest</a></span></li><li><span><a href="#Data-Cleaning" data-toc-modified-id="Data-Cleaning-7.3"><span class="toc-item-num">7.3&nbsp;&nbsp;</span>Data Cleaning</a></span></li><li><span><a href="#Calculate-Impermanent-Loss" data-toc-modified-id="Calculate-Impermanent-Loss-7.4"><span class="toc-item-num">7.4&nbsp;&nbsp;</span>Calculate Impermanent Loss</a></span></li><li><span><a href="#Calculate-rate-change" data-toc-modified-id="Calculate-rate-change-7.5"><span class="toc-item-num">7.5&nbsp;&nbsp;</span>Calculate rate change</a></span></li></ul></li><li><span><a href="#Ethereum-MacroData" data-toc-modified-id="Ethereum-MacroData-8"><span class="toc-item-num">8&nbsp;&nbsp;</span>Ethereum MacroData</a></span><ul class="toc-item"><li><span><a href="#Data-Collection" data-toc-modified-id="Data-Collection-8.1"><span class="toc-item-num">8.1&nbsp;&nbsp;</span>Data Collection</a></span></li><li><span><a href="#Data-Cleaning" data-toc-modified-id="Data-Cleaning-8.2"><span class="toc-item-num">8.2&nbsp;&nbsp;</span>Data Cleaning</a></span></li></ul></li><li><span><a href="#Exploratory-Data-Analysis-on-NVH" data-toc-modified-id="Exploratory-Data-Analysis-on-NVH-9"><span class="toc-item-num">9&nbsp;&nbsp;</span>Exploratory Data Analysis on NVH</a></span><ul class="toc-item"><li><span><a href="#Statistical-Distributions" data-toc-modified-id="Statistical-Distributions-9.1"><span class="toc-item-num">9.1&nbsp;&nbsp;</span>Statistical Distributions</a></span></li><li><span><a href="#Approach-1:-Group-by-quantile" data-toc-modified-id="Approach-1:-Group-by-quantile-9.2"><span class="toc-item-num">9.2&nbsp;&nbsp;</span>Approach 1: Group by quantile</a></span></li><li><span><a href="#Approach-2:-Remove-outliers" data-toc-modified-id="Approach-2:-Remove-outliers-9.3"><span class="toc-item-num">9.3&nbsp;&nbsp;</span>Approach 2: Remove outliers</a></span></li><li><span><a href="#Correlation-with-other-features" data-toc-modified-id="Correlation-with-other-features-9.4"><span class="toc-item-num">9.4&nbsp;&nbsp;</span>Correlation with other features</a></span><ul class="toc-item"><li><span><a href="#Relationship-with-time_in_pool_days" data-toc-modified-id="Relationship-with-time_in_pool_days-9.4.1"><span class="toc-item-num">9.4.1&nbsp;&nbsp;</span>Relationship with time_in_pool_days</a></span></li><li><span><a href="#Relationship-with-eth_rate_burn" data-toc-modified-id="Relationship-with-eth_rate_burn-9.4.2"><span class="toc-item-num">9.4.2&nbsp;&nbsp;</span>Relationship with eth_rate_burn</a></span></li><li><span><a href="#Relationship-with-eth_rate_mint" data-toc-modified-id="Relationship-with-eth_rate_mint-9.4.3"><span class="toc-item-num">9.4.3&nbsp;&nbsp;</span>Relationship with eth_rate_mint</a></span></li><li><span><a href="#Relationship-with-usdc_burned-v.s.-eth_burned" data-toc-modified-id="Relationship-with-usdc_burned-v.s.-eth_burned-9.4.4"><span class="toc-item-num">9.4.4&nbsp;&nbsp;</span>Relationship with usdc_burned v.s. eth_burned</a></span></li><li><span><a href="#Relationship-with-mint_vol-and-burn_vol-(volatility)" data-toc-modified-id="Relationship-with-mint_vol-and-burn_vol-(volatility)-9.4.5"><span class="toc-item-num">9.4.5&nbsp;&nbsp;</span>Relationship with mint_vol and burn_vol (volatility)</a></span></li></ul></li></ul></li><li><span><a href="#Machine-Learning-on-NVH" data-toc-modified-id="Machine-Learning-on-NVH-10"><span class="toc-item-num">10&nbsp;&nbsp;</span>Machine Learning on NVH</a></span><ul class="toc-item"><li><span><a href="#Linear-regression" data-toc-modified-id="Linear-regression-10.1"><span class="toc-item-num">10.1&nbsp;&nbsp;</span>Linear regression</a></span><ul class="toc-item"><li><span><a href="#Linear-Regression-for-Burn-Related-Features-Only" data-toc-modified-id="Linear-Regression-for-Burn-Related-Features-Only-10.1.1"><span class="toc-item-num">10.1.1&nbsp;&nbsp;</span>Linear Regression for Burn-Related Features Only</a></span></li><li><span><a href="#Linear-Regression-for-Mint-Related-Features-Only" data-toc-modified-id="Linear-Regression-for-Mint-Related-Features-Only-10.1.2"><span class="toc-item-num">10.1.2&nbsp;&nbsp;</span>Linear Regression for Mint-Related Features Only</a></span></li></ul></li><li><span><a href="#Ridge-regression" data-toc-modified-id="Ridge-regression-10.2"><span class="toc-item-num">10.2&nbsp;&nbsp;</span>Ridge regression</a></span></li><li><span><a href="#Lasso-regression" data-toc-modified-id="Lasso-regression-10.3"><span class="toc-item-num">10.3&nbsp;&nbsp;</span>Lasso regression</a></span><ul class="toc-item"><li><span><a href="#Alpha-=-0.1" data-toc-modified-id="Alpha-=-0.1-10.3.1"><span class="toc-item-num">10.3.1&nbsp;&nbsp;</span>Alpha = 0.1</a></span></li><li><span><a href="#Alpha-=-1" data-toc-modified-id="Alpha-=-1-10.3.2"><span class="toc-item-num">10.3.2&nbsp;&nbsp;</span>Alpha = 1</a></span></li><li><span><a href="#Alpha-=-10" data-toc-modified-id="Alpha-=-10-10.3.3"><span class="toc-item-num">10.3.3&nbsp;&nbsp;</span>Alpha = 10</a></span></li></ul></li><li><span><a href="#Random-Forrest" data-toc-modified-id="Random-Forrest-10.4"><span class="toc-item-num">10.4&nbsp;&nbsp;</span>Random Forrest</a></span><ul class="toc-item"><li><span><a href="#Random-Forrest-on-Raw-Data" data-toc-modified-id="Random-Forrest-on-Raw-Data-10.4.1"><span class="toc-item-num">10.4.1&nbsp;&nbsp;</span>Random Forrest on Raw Data</a></span></li><li><span><a href="#Random-Forrest-on-Quartiles" data-toc-modified-id="Random-Forrest-on-Quartiles-10.4.2"><span class="toc-item-num">10.4.2&nbsp;&nbsp;</span>Random Forrest on Quartiles</a></span></li></ul></li><li><span><a href="#Extra-tests-on-features" data-toc-modified-id="Extra-tests-on-features-10.5"><span class="toc-item-num">10.5&nbsp;&nbsp;</span>Extra tests on features</a></span></li></ul></li><li><span><a href="#Extraneous-Machine-Learning" data-toc-modified-id="Extraneous-Machine-Learning-11"><span class="toc-item-num">11&nbsp;&nbsp;</span>Extraneous Machine Learning</a></span><ul class="toc-item"><li><span><a href="#KNN-Classification:-Classifying-Action-based-on-ETH-Volume" data-toc-modified-id="KNN-Classification:-Classifying-Action-based-on-ETH-Volume-11.1"><span class="toc-item-num">11.1&nbsp;&nbsp;</span>KNN Classification: Classifying Action based on ETH Volume</a></span></li><li><span><a href="#Actual-Gain-vs.-Time-Spent-in-Pool" data-toc-modified-id="Actual-Gain-vs.-Time-Spent-in-Pool-11.2"><span class="toc-item-num">11.2&nbsp;&nbsp;</span>Actual Gain vs. Time Spent in Pool</a></span></li><li><span><a href="#Actual-gain-vs.-rate-change" data-toc-modified-id="Actual-gain-vs.-rate-change-11.3"><span class="toc-item-num">11.3&nbsp;&nbsp;</span>Actual gain vs. rate change</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Introduction

# %% [markdown]
# ## Data Dictionary
# - `action_name`: BURN, MINT, or SWAP <br>
# - `timestamp`: Unix time <br>
# - `newly_added_usdc`: positive/negative number according to burn/mint/swap activities <br>
# - `newly_added_eth`: positive/negative number according to burn/mint/swap activities <br>
# - `transaction.id`: wallet ID for each wallet in the pool <br>
# - `cum_sum_ETH`: previous culmulative ETH + ETH added <br>
# - `cum_sum_USDC`: previous culmulative USDC + USDC added <br>
# - `ETH Rate`: use `cum_sum_USDC` / `cum_sum_ETH` to get how much dollar 1 ETH worth with respect to different liquidity activities <br>
# - `personal_perc`: front_fill() for swap (ownership does not change for swaps), burn and mint activities with functions below <br>
# - `impermanent_loss`: 1 - liquidity providing value / hold value <br>
# - `amount0In`, `amount1In`, `amount0Out`, `amount1Out`: coin 0 (usdc) and coin 1 (ETH) in and out for SWAP action <br>
# - `amount0`, `amount1`: coin 0 (usdc) and coin 1 (ETH) in and out for BURN and MINT action, burn is negative and mint is positive <br>
# - `transaction_fee_gained`: transaction fee gained after swaps; note: there's a 0.3% fee for swaps, 0.25% of fee given to LP, remaining 0.05% to SUSHI token holders <br>

# %% [markdown]
# ## Additional Notes
# 1. ETH to USDC ratio should not change for the burn and mint activities <br>
# 2. For simplicity, we assume each person enters the pool once and stays in the pool <br>
# 3. USDC price will be calculated as 1 dollar <br>
# 4. Sushi Swap Data is initiated with a SWAP, therefore an temporary initial liquidity is calculated as below: <br>
#
# assume x = initial USDC and y = initial ETH <br>
# we can come up with a system of equations from the equality: `(x + swaps_x) / (y + swaps_y) = (next_mint_x) / (next_mint_y)` <br>
# using the first two sets of swaps and burn/mint, we get a result: approximately 410724337.7 USDC and 1112980.847 ETH at the beginning of the pool

# %% [markdown]
# ## Imports

# %%
# Basics
import pandas as pd
import numpy as np
import scipy
import time

# Files 
import glob
import os
import os.path
from zipfile import ZipFile

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import confusion_matrix
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
from sklearn import linear_model

# Statistics
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# API
from IPython.display import Image
from IPython.core.display import HTML 
import requests

# %%
pd.set_option('display.max_columns', None)

# %% [markdown]
# # Uniswap Data: Exploratory Analysis

# %%
data_dir = '/Users/samantha/MATH446/MATH446_project/dario_burnmint_data'
burn_mint = pd.read_csv(os.path.join(data_dir, "BurnMint.csv"))
swaps = pd.read_csv(os.path.join(data_dir, "Swaps.csv"))

# %% [markdown]
# Convert the block height in both dataframes to float in order to sort them later

# %%
burn_mint.loc[:,'BLOCK_HEIGHT'] = burn_mint.loc[:,'BLOCK_HEIGHT'].astype(float)
swaps.loc[:,'BLOCK_HEIGHT'] = swaps.loc[:,'BLOCK_HEIGHT'].astype(float)

# %% [markdown]
# ## Create dataset with only transactions in DAI-ETH pool
# Create a dummy variable to identify the token pairs in each of BurnMint and Swaps

# %%
burn_mint['TOKEN_PAIR']=burn_mint['TOKEN_0_TICKER_SYMBOL'] + burn_mint['TOKEN_1_TICKER_SYMBOL']
swaps['TOKEN_PAIR']=swaps['TOKEN_0_TICKER_SYMBOL'] + swaps['TOKEN_1_TICKER_SYMBOL']

# %% [markdown]
# Double check whether the tokens ever switch places, i.e. will DAI-ETH pool appear as DAIWETH and WETHDAI?

# %%
burn_mint.loc[burn_mint['TOKEN_0_TICKER_SYMBOL'] == 'DAI'] # has 38,121 rows
swaps.loc[swaps['TOKEN_0_TICKER_SYMBOL'] == 'DAI'] # has 350,726 rows
burn_mint.loc[burn_mint['TOKEN_1_TICKER_SYMBOL'] == 'DAI'] # has 0 rows
swaps.loc[swaps['TOKEN_1_TICKER_SYMBOL'] == 'DAI'] # has 0 rows
# Out:
# Empty DataFrame
# Columns: [ADDRESS_FROM, ADDRESS_TO, AMOUNT0_IN, AMOUNT0_OUT, AMOUNT1_IN, AMOUNT1_OUT, BLOCK_HEIGHT, BLOCK_SIGNED_AT, EVENT_TYPE, POOL_ADDRESS, POOL_DECIMALS, POOL_NAME, POOL_TICKER_SYMBOL, TOKEN_0, TOKEN_0_DECIMALS, TOKEN_0_NAME, TOKEN_0_TICKER_SYMBOL, TOKEN_1, TOKEN_1_DECIMALS, TOKEN_1_NAME, TOKEN_1_TICKER_SYMBOL, TX_HASH, TOKEN_PAIR]
# Index: []

# %% [markdown]
# After running each of these, we find that DAI only appears in the TOKEN_0 column for both datasets. Therefore, we will only find this token pair under "DAIWETH" in column TOKEN_PAIR.

# %%
# Set the token_pair dummy variable to a string
swaps.loc[:,'TOKEN_PAIR'] = swaps.loc[:,'TOKEN_PAIR'].astype(str)
burn_mint.loc[:,'TOKEN_PAIR'] = burn_mint.loc[:,'TOKEN_PAIR'].astype(str)
# Set token_pair as index to make it easier to locate the 'DAIWETH' rows
swaps = swaps.set_index('TOKEN_PAIR')
burn_mint = burn_mint.set_index('TOKEN_PAIR')

# %%
# Build daiweth datasets of the respective swaps and burnmints
daiweth_swaps = swaps.loc[['DAIWETH']]
daiweth_burnmint = burn_mint.loc[['DAIWETH']]

# %% [markdown]
# Merge swaps with burnmints using outer merge in pandas to obtain all DAI-ETH transactions

# %%
daiweth = pd.merge(daiweth_burnmint, daiweth_swaps, how='outer')

# %% [markdown]
# Index and sort block height in order to display transactions chronologically.

# %%
daiweth = daiweth.set_index('BLOCK_HEIGHT')
daiweth.sort_index()
# Now we have our dataset of all transactions in this pool across the 5 months of uniswap data
# Out:
#                      BLOCK_SIGNED_AT EVENT_TYPE         LOGGED_AMOUNT0  \
# BLOCK_HEIGHT
# 10060850.00000  2020-05-14T06:43:06Z       MINT  200000000000000000000
# 10060922.00000  2020-05-14T07:01:38Z       SWAP                    NaN
# 10060952.00000  2020-05-14T07:08:01Z       SWAP                    NaN
# 10060958.00000  2020-05-14T07:10:30Z       MINT    6768760548716217559
# 10062519.00000  2020-05-14T12:59:41Z       MINT    2208293366787957837
# ...                              ...        ...                    ...
# 11099989.00000  2020-10-21T21:11:33Z       SWAP                    NaN
# 11099989.00000  2020-10-21T21:11:33Z       SWAP                    NaN
# 11099989.00000  2020-10-21T21:11:33Z       SWAP                    NaN
# 11099997.00000  2020-10-21T21:13:22Z       SWAP                    NaN
# 11099998.00000  2020-10-21T21:13:28Z       SWAP                    NaN
#
#                      LOGGED_AMOUNT1  \
# BLOCK_HEIGHT
# 10060850.00000  1000000000000000000
# ...

# %% [markdown]
# At this point, we realized that the burns and mints did not have the wallet address data that would be necessary to calculate the impermanent loss for each address. While some teammates worked on testing whether we'd be able to pull wallet addresses from Etherscan (since we have the transaction hashes), we worked on simplifying the data we had and converting it into a useful format.

# %% [markdown]
# ## More work with combined Uniswap dataset

# %% [markdown]
# ### Time series of DAI and ETH in pool
# We found a source with chronological data with a daily amount of each token in Uniswap DAI-ETH

# %%
# import
liquidity_comp = pd.read_csv(os.path.join(data_dir, 'liquidity_comparison.csv'))
# Reduce to only having rows corresponding to days that are in our 5 month sample, ending Oct 21 2020
liquidity_comp = liquidity_comp[0:158]

# %% [markdown]
# We decided to rename the daiweth dataframe to dai_eth_actions in order to differentiate it from our dataset about token holders

# %%
dai_eth_actions = dai_eth_actions = pd.read_csv(os.path.join(data_dir, "daiweth.csv"))
dai_eth_holders = pd.read_csv(os.path.join(data_dir, "DAI-ETH.csv"))
# Drop irrelevant columns
dai_eth_holders = dai_eth_holders.drop(['CONTRACT_NAME', 'LOGO_URL', 'CONTRACT_TICKER_SYMBOL'],axis=1)
dai_eth_actions = dai_eth_actions.drop(['POOL_ADDRESS', 'POOL_TICKER_SYMBOL', 'POOL_TICKER_SYMBOL', 'TOKEN_0_NAME','TOKEN_1_NAME', 'TOKEN_0_DECIMALS','TOKEN_1_DECIMALS'],axis=1)
# Out:
# /Users/samantha/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (3,4,18,19,20,21,22,23) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %% [markdown]
# We calculated the going exchange rate between ETH and DAI in dai_eth_actions and liquidity_comp to ensure that our data made sense.

# %%
liquidity_comp['EXCH_RATE'] = liquidity_comp['DAI'].astype(float) / liquidity_comp['ETH'].astype(float)
dai_eth_actions['EXCH_RATE'] = dai_eth_actions['LOGGED_AMOUNT0'].astype(float) / dai_eth_actions['LOGGED_AMOUNT1'].astype(float)
# the exchange rate over time confirms that our data make sense in context with each other

# %% [markdown]
# ## Find how much DAI and ETH each wallet in the pool owns

# %% [markdown]
# We only have ownership data at block 11,100,000 (ie. the end of the 5 month period of our dataset). Thus we can calculate the amount owned for each address in dai_eth_actions at that point in time. Start by calculating what percentage of the pool each address owns.

# %%
dai_eth_holders['PERCENT_OWNED'] = dai_eth_holders['BALANCE'].astype(float) / dai_eth_holders['TOTAL_SUPPLY'].astype(float)

# %% [markdown]
# Fill in amount of DAI & ETH owned in token holders csv based on oct 21 data from liquidity_comp

# %%
dai_eth_holders['DAI_OWNED'] = dai_eth_holders['PERCENT_OWNED']*liquidity_comp.loc[157]['DAI']
dai_eth_holders['ETH_OWNED'] = dai_eth_holders['PERCENT_OWNED']*liquidity_comp.loc[157]['ETH']

# %% [markdown]
# Now we know the exact amount of DAI and ETH each of the wallet addresses in the pool owns as of block 11,100,000. If we had been able to identify which addresses were burning and minting, this would be very useful data.

# %% [markdown]
# ## Simplify actions dataset
# Next, we created a dataset which combines burn, mint, and swap transactions into a simple +/- change of DAI and ETH in the pool. Start by filling in NaN's with 0s in order to add and subtract the total change in a transaction. We can do this because a burn or mint will have 0 in swap columns and vice versa.

# %%
dai_eth_actions['LOGGED_AMOUNT0'] = dai_eth_actions['LOGGED_AMOUNT0'].fillna(0).astype(float)
dai_eth_actions['LOGGED_AMOUNT1'] = dai_eth_actions['LOGGED_AMOUNT1'].fillna(0).astype(float)
dai_eth_actions['AMOUNT0_IN'] = dai_eth_actions['AMOUNT0_IN'].fillna(0).astype(float)
dai_eth_actions['AMOUNT1_IN'] = dai_eth_actions['AMOUNT1_IN'].fillna(0).astype(float)
dai_eth_actions['AMOUNT0_OUT'] = dai_eth_actions['AMOUNT0_OUT'].fillna(0).astype(float)
dai_eth_actions['AMOUNT1_OUT'] = dai_eth_actions['AMOUNT1_OUT'].fillna(0).astype(float)

# %% [markdown]
# For each token, we perform the following: burn/mintDAI + swapDAIin - swapDAIout. Simply put, this gives us the amount of DAI and ETH involved in the transaction, including a negative number for the amount that goes out of the pool in a swap. We will go back and switch the burns to a negative in the next step. We divide by 10^18 to get it into the actual number form.

# %%
dai_eth_actions['DAI_CHANGE'] = (dai_eth_actions['LOGGED_AMOUNT0']+dai_eth_actions['AMOUNT0_IN']-dai_eth_actions['AMOUNT0_OUT'])/(10**18)
dai_eth_actions['ETH_CHANGE'] = (dai_eth_actions['LOGGED_AMOUNT1']+dai_eth_actions['AMOUNT1_IN']-dai_eth_actions['AMOUNT1_OUT'])/(10**18)

# %% [markdown]
# Use a for loop to identify all burn transactions and change the sign to a negative number, reflecting the shrinking of the pool when burns take place.

# %%
for i in range(1,len(dai_eth_actions)):
    if dai_eth_actions.loc[i]['EVENT_TYPE'] == 'BURN':
        dai_eth_actions.at[i,'DAI_CHANGE'] = -1* dai_eth_actions.at[i,'DAI_CHANGE']
        dai_eth_actions.at[i,'ETH_CHANGE'] = -1* dai_eth_actions.at[i,'ETH_CHANGE']

# %% [markdown]
# Create simplified dataframe to show changes in ETH and DAI in pool for each given transaction

# %%
change_in_pool = dai_eth_actions.drop(['AMOUNT0_IN', 'AMOUNT1_IN', 'AMOUNT0_OUT', 'AMOUNT1_OUT','TOKEN_1','TOKEN_0','LOGGED_AMOUNT0','LOGGED_AMOUNT1','POOL_DECIMALS','POOL_NAME','TX_HASH','TOKEN_0_TICKER_SYMBOL','TOKEN_1_TICKER_SYMBOL','ADDRESS_FROM','ADDRESS_TO'],axis=1)
change_in_pool
# Out:
#         BLOCK_HEIGHT       BLOCK_SIGNED_AT EVENT_TYPE  EXCH_RATE  DAI_CHANGE  \
# 0           10064415  2020-05-14T19:58:48Z       BURN  204.23887     0.01020
# 1           10064794  2020-05-14T21:23:37Z       BURN  201.37576    -1.00778
# 2           10065717  2020-05-15T00:49:30Z       BURN  211.41600    -0.24877
# 3           10066055  2020-05-15T02:15:55Z       BURN  211.81795    -6.96962
# 4           10069817  2020-05-15T15:59:01Z       BURN  210.07097    -1.05095
# ...              ...                   ...        ...        ...         ...
# 388842      11099989  2020-10-21T21:11:33Z       SWAP        NaN  -268.81405
# 388843      11099989  2020-10-21T21:11:33Z       SWAP        NaN 14200.00000
# 388844      11099989  2020-10-21T21:11:33Z       SWAP        NaN   -37.97442
# 388845      11099997  2020-10-21T21:13:22Z       SWAP        NaN -5026.39156
# 388846      11099998  2020-10-21T21:13:28Z       SWAP        NaN   200.00000
#
#         ETH_CHANGE
# 0          0.00005
# ...

# %% [markdown]
# With this, it would be possible to calculate impermanent loss for the 5-month period if we had a way of obtaining the wallet addresses that the transactions corresponded to. (It was at this point that we decided to pivot our efforts to the sushiswap data that Neel was able to pull.

# %% [markdown]
# # SushiSwap Data: Initialization

# %% [markdown]
# Combine all of Neel's SushiSwap data into one large DataFrame

# %% [markdown]
# Initial liquidity (September 11, 2020):
# - $190,088,571.59
# - Price of ETH to USDC at market open on September 11: 368.12
#
# $190,088,571.59 / (368.12^2 + 1) = 1402.7296459912068$

# %%
initial_eth_in_pool = 190088571.59 / (368.12*2)
initial_eth_in_pool
# Out:
# 258188.3239025318

# %%
initial_usdc_in_pool = initial_eth_in_pool*368.12
initial_usdc_in_pool
# Out:
# 95044285.795

# %% [markdown]
# ### Mints

# %%
mints = pd.concat(map(pd.read_csv, glob.glob('/Users/samantha/MATH446/MATH446_project/sushiswap_data/sushi_mints/*.csv')))
mints['action_name'] = 'MINT'
mints.head()
# Out:
#       amount0  amount1    amountUSD  feeLiquidity  feeTo  \
# 0   574.48166  0.17474   1147.10747           NaN    NaN
# 1  1311.31748  0.40015   2620.91809           NaN    NaN
# 2  5593.12256  1.70675  11178.21736           NaN    NaN
# 3 62330.22136 18.99923 124545.42682           NaN    NaN
# 4  4984.33373  1.51843   9959.23114           NaN    NaN
#
#                                                   id  liquidity  logIndex  \
# 0  0x695d087b62a730ee0793acaaa6e2413357c563eba326...    0.00000        69
# 1  0x60051f48b99561c8f297559648ecc23558eb6dbe394e...    0.00000       246
# 2  0x361ebab5a71583293b74765226ba92dfbb3859906262...    0.00000       100
# 3  0xf8b593af076e445d50c47550645f1e6198d9649997d1...    0.00000       193
# 4  0xd05ea8f94cf52348c6e42dc00f2b40b2540fea88e0c9...    0.00000       234
#
#                                        sender   timestamp  \
# 0  0xd9e1ce17f2641f24ae83637ab66a2cca9c378b9f  1633160808
# ...

# %% [markdown]
# ### Burns

# %%
burns = pd.concat(map(pd.read_csv, glob.glob('/Users/samantha/MATH446/MATH446_project/sushiswap_data/sushi_burns/*.csv')))
burns['action_name'] = 'BURN'
burns.head()
# Out:
#       amount0  amount1   amountUSD  complete  feeLiquidity  \
# 0    53.15560  0.01622   106.23467     False       0.00000
# 1 33429.99772 10.19956 66802.06608     False       0.00000
# 2 34128.89488 10.39662 68332.12133     False       0.00000
# 3 33034.68690 10.00513 66068.75457     False       0.00000
# 4  5096.18041  1.54499 10187.64567     False       0.00000
#
#                                         feeTo  \
# 0  0xe11fc0b43ab98eb91e9836129d1ee7c3bc95df50
# 1  0xe11fc0b43ab98eb91e9836129d1ee7c3bc95df50
# 2  0xe11fc0b43ab98eb91e9836129d1ee7c3bc95df50
# 3  0xe11fc0b43ab98eb91e9836129d1ee7c3bc95df50
# 4  0xe11fc0b43ab98eb91e9836129d1ee7c3bc95df50
#
#                                                   id  liquidity  logIndex  \
# 0  0x936805cb4d012886f76dba41af99490bbfe58090c7d9...    0.00000        18
# 1  0x40ae1f2ec9393cdf0c3dccbac0e280eba5ef0edef736...    0.00040        16
# 2  0x692c11b5a88bafe38e33ed53c9d69f2e654546c1c56a...    0.00041        46
# ...

# %% [markdown]
# ### Swaps

# %%
swaps = pd.concat(map(pd.read_csv, glob.glob('/Users/samantha/MATH446/MATH446_project/sushiswap_data/sushi_swaps/*.csv')))
swaps['action_name'] = 'SWAP'
swaps.head()
# Out:
#    amount0In  amount0Out  amount1In  amount1Out   amountUSD  \
# 0    0.00000   655.69117    0.20000     0.00000   655.73910
# 1 3187.37127     0.00000    0.00000     0.96638  3178.41634
# 2    0.00000  2474.43390    0.75474     0.00000  2472.89261
# 3    0.00000 12256.35281    3.73868     0.00000 12250.44013
# 4    0.00000   140.42275    0.04284     0.00000   140.36396
#
#                                                   id  logIndex  \
# 0  0x4d8ef545d36dde6624bcdfdb456f86dcff62ada993c5...        29
# 1  0x8588d600669d558b7f0d01497b4b0d7d52ed68bd6a3a...       233
# 2  0x0e003fd28cf7b9aa3fc2f928803bbc9aac3bf89b1d87...       289
# 3  0x9b9bc6aaece3fc02c558d6cbaacae49f6f02e16bcaf9...       229
# 4  0x0a05c0f953fbf14efb9737bb626cd5ae4c0b2f91751b...       370
#
#                                        sender   timestamp  \
# 0  0xf9234cb08edb93c0d4a4d4c70cc3ffd070e78e07  1633158467
# 1  0xd9e1ce17f2641f24ae83637ab66a2cca9c378b9f  1633158512
# ...

# %% [markdown]
# ### Concatenate Burns, Mints, and Swaps into one large dataframe

# %%
all_data = pd.concat([burns, mints, swaps])
all_data = all_data.sort_values(by='timestamp')
all_data.head()
# Out:
#      amount0  amount1   amountUSD complete  feeLiquidity feeTo  \
# 0        NaN      NaN  5491.16790      NaN           NaN   NaN
# 1        NaN      NaN  9052.04917      NaN           NaN   NaN
# 0 5453.84611 14.77989 10828.87768      NaN           NaN   NaN
# 2        NaN      NaN  6764.01439      NaN           NaN   NaN
# 3        NaN      NaN 59428.29749      NaN           NaN   NaN
#
#                                                   id  liquidity  logIndex  \
# 0  0xe2795bffac25dc445729a551b113fd2593bd05366a38...        NaN         7
# 1  0x98ad2ce4e852e71f078bf094389d65b13dcae781bac1...        NaN        49
# 0  0x52bcbdf36c0be477bd2969c448db91ff31f12ece30ac...    0.00000        52
# 2  0x8607e89c83a2f5d88e06ed22540244362ac3e4327ac2...        NaN       108
# 3  0xbfa95ea7d45747fdcbf3cadca19b7f3aeae1f124b031...        NaN        69
#
#                                        sender   timestamp  \
# 0  0xd9e1ce17f2641f24ae83637ab66a2cca9c378b9f  1599721625
# ...

# %% [markdown]
# ### Convert datatypes

# %%
all_data['timestamp'] = pd.to_datetime(all_data['timestamp'],unit='s')

# %%
min(all_data['timestamp'])
# Out:
# Timestamp('2020-09-10 07:07:05')

# %%
max(all_data['timestamp'])
# Out:
# Timestamp('2021-12-01 23:55:05')

# %% [markdown]
# # Sushiswap Wallet Address Analysis

# %%
pd.set_option('display.float_format',lambda x: '%.5f'%x)

# %%
fromcount = mints['sender'].nunique()
fromcount
# Out:
# 21

# %%
tocount = mints['to'].nunique()
tocount
# Out:
# 527

# %%
sendercounts = burns['sender'].nunique()
sendercounts
# Out:
# 2979

# %%
tocounts = burns['to'].nunique()
tocounts
# Out:
# 1

# %% [markdown]
# So, the 'sender' count for burns and the 'to' count for mints appear to be the wallet addresses, but if we:

# %%
mints['to'].value_counts()
# Out:
# 0xe11fc0b43ab98eb91e9836129d1ee7c3bc95df50    8096
# 0x6684977bbed67e101bb80fc07fccfba655c0a64f    1294
# 0x280ac711bb99de7c73fb70fb6de29846d5e4207f     892
# 0x95c69c3220b31b843f1cf20bee5c53fcde7fc12e     104
# 0xc37ed5574333dcd44efd0a615b6acd1e322a8401      12
#                                               ...
# 0xae699306adec168e32ec1fe369043a1fc093738a       1
# 0x4e81a2a6652f9e2b85cecaf067c36bec685bfeca       1
# 0x1da8469b048592baa0aa4fa28842a9e63bcfdc8c       1
# 0x6de4e04ee77726dd586c1dbc8dfbe907b523ea11       1
# 0x6014ba1e29605cdd33d5d95c01b79275aa494be9       1
# Name: to, Length: 527, dtype: int64

# %% [markdown]
# But if we search some of the addresses with higher transaction volume on https://etherscan.io/, we see that they are contract addresses, but the ones with lower transaction volumes < 5 are almost all wallet addresses. This holds true for the burns set as well, with the only difference being that the volume is more spread out and not quite as top heavy.
#
# This is the same problem we had with the etherscan API. We currently are only looking at wallets with smaller transaction volume which ensures that they are in fact wallet addresses, but should we treat contract transactions differently from wallet transactions?
#
#
# The following is a burn transaction from the etherscan API fetched using a transaction hash from the uniswap data. The second row of 'to' contains the wallet adress we need. Using a for loop on the uniswap data, we could easily assign a wallet address to every transaction.

# %%
url = "https://api.etherscan.io/api?module=account&action=txlistinternal&txhash=0x6522ae75d2935439a82da16d684a95797cd20c6caa37793461866e99488b9fbc&apikey=3AIMT2NQP1VBQV8IWGRPUWDXR6TG5XCNA6"
response = requests.get(url)
content = response.json()
result = content.get("result")
data = pd.DataFrame(result)
data
# Out:
#   blockNumber   timeStamp                                        from  \
# 0    10117564  1590176386  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2
# 1    10117564  1590176386  0xf164fc0ec4e93095b804a4795bbe1e041497b92a
#
#                                            to               value  \
# 0  0xf164fc0ec4e93095b804a4795bbe1e041497b92a  237274634864632171
# 1  0x09bad7284c92af5fd501c707522188ee2d5b2125  237274634864632171
#
#   contractAddress input  type    gas gasUsed isError errCode
# 0                        call   2300      83       0
# 1                        call  29020       0       0

# %% [markdown]
# But we run into the same problem when fetching a mint transaction. The following table contains all contract addresses, but some of the mints also contain wallet addresses.

# %%
url = "https://api.etherscan.io/api?module=account&action=txlistinternal&txhash=0x10d0c21b4722533ba9bf7f01ea7abd511f3f92fae8a376e8d1ad86491010beaf&apikey=3AIMT2NQP1VBQV8IWGRPUWDXR6TG5XCNA6"
response = requests.get(url)
content = response.json()
result = content.get("result")
data = pd.DataFrame(result)
data
# Out:
#   blockNumber   timeStamp                                        from  \
# 0    10051195  1589283960  0x83d836a5b96a886abc57f84775f6165614dcf8d6
# 1    10051195  1589283960  0x379b4609bdf93b3584cf7b64bc78199cf185f1cd
#
#                                            to              value  \
# 0  0x379b4609bdf93b3584cf7b64bc78199cf185f1cd  10000000000000000
# 1  0xc02aaa39b223fe8d0a0e5c4f27ead9083c756cc2  10000000000000000
#
#   contractAddress input  type     gas gasUsed isError errCode
# 0                        call  854816  269737       0
# 1                        call  832275   22674       0

# %% [markdown]
# So, if we could figure out how to treat these contract to contract interactions vs wallet to wallet transactions, we would be able to get an absolutely massive dataset and probably generalize some of the algorithms we have been working on.

# %% [markdown]
# # Calculate Inputs for Impermanent Loss

# %% [markdown]
# ## Cumulative Sum

# %% [markdown]
# ### USDC

# %%
all_data = all_data.fillna(0)
all_data = all_data.reset_index()

# %% [markdown]
# Staring point: 410724337.661123 USDC, 1112980.84650377 ETH

# %%
all_data['newly_added_usdc'] = all_data['amount0'] + all_data['amount0In'] - all_data['amount0Out']

# %%
for i in range(1,len(all_data)):
    if all_data.loc[i]['action_name'] == 'BURN':
        all_data.at[i,'newly_added_usdc'] = -1* all_data.at[i,'newly_added_usdc']

# %%
# Hard code starting point
all_data['newly_added_usdc'][0] = 410724337.661123 + all_data['newly_added_usdc'][0]
all_data['cum_sum_usdc'] = all_data['newly_added_usdc'].cumsum()
all_data.head()
# Out:
# <ipython-input-769-60fbbb83f1bf>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['newly_added_usdc'][0] = 410724337.661123 + all_data['newly_added_usdc'][0]
#    index    amount0  amount1   amountUSD complete  feeLiquidity feeTo  \
# 0      0    0.00000  0.00000  5491.16790        0       0.00000     0
# 1      1    0.00000  0.00000  9052.04917        0       0.00000     0
# 2      0 5453.84611 14.77989 10828.87768        0       0.00000     0
# 3      2    0.00000  0.00000  6764.01439        0       0.00000     0
# 4      3    0.00000  0.00000 59428.29749        0       0.00000     0
#
#                                                   id  liquidity  logIndex  \
# 0  0xe2795bffac25dc445729a551b113fd2593bd05366a38...    0.00000         7
# ...

# %% [markdown]
# ### ETH

# %%
all_data['newly_added_eth'] = all_data['amount1'] + all_data['amount1In'] - all_data['amount1Out']
all_data.head()
# Out:
#    index    amount0  amount1   amountUSD complete  feeLiquidity feeTo  \
# 0      0    0.00000  0.00000  5491.16790        0       0.00000     0
# 1      1    0.00000  0.00000  9052.04917        0       0.00000     0
# 2      0 5453.84611 14.77989 10828.87768        0       0.00000     0
# 3      2    0.00000  0.00000  6764.01439        0       0.00000     0
# 4      3    0.00000  0.00000 59428.29749        0       0.00000     0
#
#                                                   id  liquidity  logIndex  \
# 0  0xe2795bffac25dc445729a551b113fd2593bd05366a38...    0.00000         7
# 1  0x98ad2ce4e852e71f078bf094389d65b13dcae781bac1...    0.00000        49
# 2  0x52bcbdf36c0be477bd2969c448db91ff31f12ece30ac...    0.00000        52
# 3  0x8607e89c83a2f5d88e06ed22540244362ac3e4327ac2...    0.00000       108
# 4  0xbfa95ea7d45747fdcbf3cadca19b7f3aeae1f124b031...    0.00000        69
#
#                                        sender           timestamp  \
# ...

# %%
all_data['newly_added_eth'][0] = 1112980.84650377 + all_data['newly_added_eth'][0]
for i in range(1,len(all_data)):
    if all_data.loc[i]['action_name'] == 'BURN':
        all_data.at[i,'newly_added_eth'] = -1* all_data.at[i,'newly_added_eth']
all_data['cum_sum_eth'] = all_data['newly_added_eth'].cumsum()
all_data.head()
# Out:
# <ipython-input-771-9a03e6ccff52>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_data['newly_added_eth'][0] = 1112980.84650377 + all_data['newly_added_eth'][0]
#    index    amount0  amount1   amountUSD complete  feeLiquidity feeTo  \
# 0      0    0.00000  0.00000  5491.16790        0       0.00000     0
# 1      1    0.00000  0.00000  9052.04917        0       0.00000     0
# 2      0 5453.84611 14.77989 10828.87768        0       0.00000     0
# 3      2    0.00000  0.00000  6764.01439        0       0.00000     0
# 4      3    0.00000  0.00000 59428.29749        0       0.00000     0
#
#                                                   id  liquidity  logIndex  \
# 0  0xe2795bffac25dc445729a551b113fd2593bd05366a38...    0.00000         7
# ...

# %% [markdown]
# ## ETH Rate

# %% [markdown]
# Define ETH Rate = cum_sum_usdc / cum_sum_eth

# %%
all_data['eth_rate'] = all_data['cum_sum_usdc'] / all_data['cum_sum_eth']

# %%
all_data.head()
# Out:
#    index    amount0  amount1   amountUSD complete  feeLiquidity feeTo  \
# 0      0    0.00000  0.00000  5491.16790        0       0.00000     0
# 1      1    0.00000  0.00000  9052.04917        0       0.00000     0
# 2      0 5453.84611 14.77989 10828.87768        0       0.00000     0
# 3      2    0.00000  0.00000  6764.01439        0       0.00000     0
# 4      3    0.00000  0.00000 59428.29749        0       0.00000     0
#
#                                                   id  liquidity  logIndex  \
# 0  0xe2795bffac25dc445729a551b113fd2593bd05366a38...    0.00000         7
# 1  0x98ad2ce4e852e71f078bf094389d65b13dcae781bac1...    0.00000        49
# 2  0x52bcbdf36c0be477bd2969c448db91ff31f12ece30ac...    0.00000        52
# 3  0x8607e89c83a2f5d88e06ed22540244362ac3e4327ac2...    0.00000       108
# 4  0xbfa95ea7d45747fdcbf3cadca19b7f3aeae1f124b031...    0.00000        69
#
#                                        sender           timestamp  \
# ...

# %% [markdown]
# ## Personal Percent Ownership

# %%
all_data['personal_perc'] = (all_data['amount1'] / all_data['cum_sum_eth'])*100
all_data.head()
# Out:
#    index    amount0  amount1   amountUSD complete  feeLiquidity feeTo  \
# 0      0    0.00000  0.00000  5491.16790        0       0.00000     0
# 1      1    0.00000  0.00000  9052.04917        0       0.00000     0
# 2      0 5453.84611 14.77989 10828.87768        0       0.00000     0
# 3      2    0.00000  0.00000  6764.01439        0       0.00000     0
# 4      3    0.00000  0.00000 59428.29749        0       0.00000     0
#
#                                                   id  liquidity  logIndex  \
# 0  0xe2795bffac25dc445729a551b113fd2593bd05366a38...    0.00000         7
# 1  0x98ad2ce4e852e71f078bf094389d65b13dcae781bac1...    0.00000        49
# 2  0x52bcbdf36c0be477bd2969c448db91ff31f12ece30ac...    0.00000        52
# 3  0x8607e89c83a2f5d88e06ed22540244362ac3e4327ac2...    0.00000       108
# 4  0xbfa95ea7d45747fdcbf3cadca19b7f3aeae1f124b031...    0.00000        69
#
#                                        sender           timestamp  \
# ...

# %% [markdown]
# # Impermanent Loss Approach 1: Calculating IL for each Wallet Address

# %% [markdown]
# Select 3 different wallets of varying sizes in order to examine individual impermanent loss for each of them

# %%
burns = pd.concat(map(pd.read_csv, glob.glob('/Users/samantha/MATH446/MATH446_project/sushiswap_data/sushi_burns/*.csv')))
mints = pd.concat(map(pd.read_csv, glob.glob('/Users/samantha/MATH446/MATH446_project/sushiswap_data/sushi_mints/*.csv')))

wallet1mint = mints.loc[mints['to'].str.contains("0x3ea6cd400a44946e9002c8fe97d29bd86526ad39", case=False)]
wallet1burn = burns.loc[burns['sender'].str.contains("0x3ea6cd400a44946e9002c8fe97d29bd86526ad39", case=False)]
frames = [wallet1mint, wallet1burn]
wallet1frame = pd.concat(frames)


wallet2mint = mints.loc[mints['to'].str.contains("0x40d47cb29eb84a75f8db202910df35a7a6a1ec72", case=False)]
wallet2burn = burns.loc[burns['sender'].str.contains("0x40d47cb29eb84a75f8db202910df35a7a6a1ec72", case=False)]
frames2 = [wallet2mint, wallet2burn]
wallet2frame = pd.concat(frames2)

wallet3mint = mints.loc[mints['to'].str.contains("0x6913a43573f51a2ab6ea238f19d6383af5a49713", case=False)]
wallet3burn = burns.loc[burns['sender'].str.contains("0x6913a43573f51a2ab6ea238f19d6383af5a49713", case=False)]
frames3 = [wallet3mint, wallet3burn]
wallet3frame = pd.concat(frames3)

# %%
wallet1frame
# Out:
#        amount0  amount1   amountUSD  feeLiquidity feeTo  \
# 16 30454.97161 17.15427 60873.26895           NaN   NaN
# 12 30455.09844 17.15420 60873.19115           NaN   NaN
#
#                                                    id  liquidity  logIndex  \
# 16  0xe7a6168c4cd9ac3c450c9d8299c302e2de876b49cc2d...    0.00055       267
# 12  0xbd4a8aebe818afeada9b1a205d578782459b1ab45e55...    0.00055        17
#
#                                         sender   timestamp  \
# 16  0xd9e1ce17f2641f24ae83637ab66a2cca9c378b9f  1615919376
# 12  0x3ea6cd400a44946e9002c8fe97d29bd86526ad39  1615919600
#
#                                             to  \
# 16  0x3ea6cd400a44946e9002c8fe97d29bd86526ad39
# 12  0x397ff1542f962076d0bfe58ea045ffa2d347aca0
#
#                                        pair.id  pair.name  \
# 16  0x397ff1542f962076d0bfe58ea045ffa2d347aca0  USDC-WETH
# 12  0x397ff1542f962076d0bfe58ea045ffa2d347aca0  USDC-WETH
#
# ...

# %%
wallet2frame
# Out:
#         amount0  amount1   amountUSD  feeLiquidity  \
# 100 10861.61427 30.00000 21500.82428           NaN
# 94  10814.53488 30.18987 21454.49162       0.00000
#
#                                           feeTo  \
# 100                                         NaN
# 94   0x6684977bbed67e101bb80fc07fccfba655c0a64f
#
#                                                     id  liquidity  logIndex  \
# 100  0x0086210de9c0861071e9cea48b989ae89067f0194878...    0.00047       297
# 94   0xfc9eb870895f25730df816ce155bdf34ab533f74b331...    0.00047       275
#
#                                          sender   timestamp  \
# 100  0xd9e1ce17f2641f24ae83637ab66a2cca9c378b9f  1599794708
# 94   0x40d47cb29eb84a75f8db202910df35a7a6a1ec72  1600023538
#
#                                              to  \
# 100  0x40d47cb29eb84a75f8db202910df35a7a6a1ec72
# 94   0x397ff1542f962076d0bfe58ea045ffa2d347aca0
#
#                                         pair.id  pair.name  \
# ...

# %%
wallet3frame
# Out:
#       amount0  amount1  amountUSD  feeLiquidity  \
# 134 800.39621  2.19504 1586.45336           NaN
# 177 800.12002  2.19580 1581.92509       0.00000
#
#                                           feeTo  \
# 134                                         NaN
# 177  0x6684977bbed67e101bb80fc07fccfba655c0a64f
#
#                                                     id  liquidity  logIndex  \
# 134  0x45a08e517fc7539a6bd63cdc4d66b68e4ee009d2b6af...    0.00003       267
# 177  0xf515ea6bb62512789810ea1950268dda28d8a956af51...    0.00003        55
#
#                                          sender   timestamp  \
# 134  0xd9e1ce17f2641f24ae83637ab66a2cca9c378b9f  1600061628
# 177  0x6913a43573f51a2ab6ea238f19d6383af5a49713  1600062226
#
#                                              to  \
# 134  0x6913a43573f51a2ab6ea238f19d6383af5a49713
# 177  0x397ff1542f962076d0bfe58ea045ffa2d347aca0
#
#                                         pair.id  pair.name  \
# ...

# %% [markdown]
# ## Initialize Impermanent loss functions

# %% [markdown]
# ### Calculation for `personal_perc`

# %% [markdown]
# When a new id mint certain percentage of coins into the pool, the person only owns previous_percentage * (1 - new_mint_perc) of the pool

# %%
def mint_percentage_change(new_eth, new_total_eth, previous_personal_percentage):
    mint_percentage = new_eth / new_total_eth
    return previous_personal_percentage * (1 - mint_percentage)

# %% [markdown]
# When a new id burn certain percentage of coins into the pool, the person will own previous_percentage * (1 + new_mint_perc) of the pool

# %%
def burn_percentage_change(new_eth, new_total_eth, previous_personal_percentage):
    burn_percentage = new_eth / new_total_eth
    return previous_personal_percentage * (1 + burn_percentage)

# %% [markdown]
# Note: swaps won't result in the change of personal percentage of the pool because the AMM curve does not move

# %%
# Calculates personal percentage using subsets of data from from all_data
def calculate_personal_percentage(df):
    i = 1
    while i < len(df):
        if df['action_name'][i] == "MINT":
            mint_perc_change = mint_percentage_change(new_eth = abs(df['amount1'][i]), 
                                   new_total_eth = df['cum_sum_eth'][i], 
                                   previous_personal_percentage = df['personal_perc'][i-1])
            df['personal_perc'][i] = mint_perc_change
        elif df['action_name'][i] == 'BURN':
            burn_perc_change = burn_percentage_change(new_eth = abs(df['amount1'][i]), 
                                   new_total_eth = df['cum_sum_eth'][i], 
                                   previous_personal_percentage = all_data['personal_perc'][i-1])
            df['personal_perc'][i] = burn_perc_change
        elif df['action_name'][i] == "SWAP":
            df['personal_perc'][i] = df['personal_perc'][i-1]
        i+=1
        # print(df['personal_perc'][i])
    return df

# %% [markdown]
# ### Calculation for `impermanent_loss`

# %% [markdown]
# To calculate `impermanent_loss`, filter swaps rows and plug in all the corresponding parameters to the function

# %%
# personal ownership column, refer to the person_eth and person_usdc at the very beginning
def hold_value(person_eth, person_usdc, new_usdc, new_eth, usdc_price):
    eth_rate = new_usdc / new_eth
    return person_eth * eth_rate * usdc_price + person_usdc * usdc_price # eth_rate is the new rate using new usdc / eth;

def liquidity_value(person_percentage, new_usdc, new_eth, usdc_price):
    eth_rate = new_usdc / new_eth
    return (person_percentage/100) * new_eth * eth_rate * usdc_price + (person_percentage/100) * new_usdc * usdc_price


# if swap, impermanent loss will change, personal percentage won't change
# start_eth_rate = last swap usdc/eth; end_eth_rate = curr swap usdc/eth
def impermanent_loss_calculation(person_eth, person_usdc, new_usdc, new_eth, usdc_price, person_percentage, eth_added):
    # exchange rate 1 ETH = how much USDC
    hold = hold_value(person_eth, person_usdc, new_usdc, new_eth, usdc_price)
    lp = liquidity_value(person_percentage, new_usdc, new_eth, usdc_price)
    impermanentLoss = 1 - lp / hold
    transaction_fee_gained = person_percentage * abs(eth_added) * 0.0025
    return impermanentLoss, transaction_fee_gained

# %%
# Adds columns with impermanent loss and transaction fee with a subset of all_data
# Inputs: 
    # df = DataFrame taking the same schema as all_data, filtered to all swaps occuring after the first mint for a given Wallet ID
    # eth_value = initial ETH value for that wallet address
    # usdc_value = initial USDC value for that wallet address
def calculate_impermanent_loss(df, eth_value, usdc_value):
    df['impermanent_loss'] = 0.0
    df['transaction_fee_gained'] = 0.0
    i = 0
    while i < len(df):
        impermanentLoss, transaction_fee_gained = impermanent_loss_calculation(person_eth = eth_value,
                                                                      person_usdc = usdc_value,
                                                                      new_usdc = df['cum_sum_usdc'][i],
                                                                      new_eth = df['cum_sum_eth'][i], 
                                                                      usdc_price = 1,
                                                                      person_percentage = df['personal_perc'][i],
                                                                      eth_added = max(abs(df['amount1'][i]), abs(df['amount1In'][i]), abs(df['amount1Out'][i])))
        df['impermanent_loss'][i] = impermanentLoss
        df['transaction_fee_gained'][i] = transaction_fee_gained
        i+=1
    return df

# %% [markdown]
# ## Create separate dataframes for each wallet

# %%
index = all_data.index

# %% [markdown]
# ### Wallet 1

# %%
# Figure out the index of first mint 
all_data[all_data['to'].str.contains("0x3ea6cd400a44946e9002c8fe97d29bd86526ad39", case=False)]
# Out:
#         index     amount0  amount1   amountUSD complete  feeLiquidity feeTo  \
# 151796     16 30454.97161 17.15427 60873.26895        0       0.00000     0
#
#                                                        id  liquidity  \
# 151796  0xe7a6168c4cd9ac3c450c9d8299c302e2de876b49cc2d...    0.00055
#
#         logIndex                                      sender  \
# 151796       267  0xd9e1ce17f2641f24ae83637ab66a2cca9c378b9f
#
#                  timestamp                                          to  \
# 151796 2021-03-16 18:29:36  0x3ea6cd400a44946e9002c8fe97d29bd86526ad39
#
#                                            pair.id  pair.name  \
# 151796  0x397ff1542f962076d0bfe58ea045ffa2d347aca0  USDC-WETH
#
#                                            transaction.id action_name  \
# 151796  0xe7a6168c4cd9ac3c450c9d8299c302e2de876b49cc2d...        MINT
#
#         amount0In  amount0Out  amount1In  amount1Out  newly_added_usdc  \
# ...

# %%
# Save index number as a variable rather than hard coding
wallet1_transaction1_index = index[all_data['to'].str.contains("0x3ea6cd400a44946e9002c8fe97d29bd86526ad39", case=False)]
wallet1_transaction1_index = wallet1_transaction1_index.tolist()
wallet1_transaction1_index = wallet1_transaction1_index[0]
wallet1_transaction1_index
# Out:
# 151796

# %%
wallet1_transactions = all_data[wallet1_transaction1_index:]
wallet1_transactions['personal_perc'] = (wallet1_transactions['amount1'] / wallet1_transactions['cum_sum_eth'])*100
# Out:
# <ipython-input-787-3cf5f5b50350>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   wallet1_transactions['personal_perc'] = (wallet1_transactions['amount1'] / wallet1_transactions['cum_sum_eth'])*100

# %%
wallet1_transactions
# Out:
#         index     amount0  amount1   amountUSD complete  feeLiquidity  \
# 151796     16 30454.97161 17.15427 60873.26895        0       0.00000
# 151797    334     0.00000  0.00000   918.06384        0       0.00000
# 151798     11  9015.97773  5.07836 18021.00075    False       0.00000
# 151799     12 30455.09844 17.15420 60873.19115    False       0.00000
# 151800    335     0.00000  0.00000  2240.96036        0       0.00000
# ...       ...         ...      ...         ...      ...           ...
# 581407   1082     0.00000  0.00000    22.65822        0       0.00000
# 581408   1083     0.00000  0.00000 24509.76347        0       0.00000
# 581409   1084     0.00000  0.00000  5004.85211        0       0.00000
# 581410   1085     0.00000  0.00000   251.39258        0       0.00000
# 581411   1086     0.00000  0.00000 20645.41204        0       0.00000
#
#                                              feeTo  \
# 151796                                           0
# ...

# %%
# Save all transactions occurring after Wallet 1's first mint as a separate DataFrame 
wallet1_transactions = wallet1_transactions.reset_index(drop=True)
wallet1_transactions_personal_perc = calculate_personal_percentage(wallet1_transactions)
# Out:
# <ipython-input-781-4a4083a85498>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['personal_perc'][i] = df['personal_perc'][i-1]
# <ipython-input-781-4a4083a85498>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['personal_perc'][i] = burn_perc_change
# <ipython-input-781-4a4083a85498>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['personal_perc'][i] = mint_perc_change

# %%
wallet1_transactions_personal_perc = wallet1_transactions_personal_perc.drop(labels=['index'], axis=1)
wallet1_transactions_personal_perc.head()
# Out:
#       amount0  amount1   amountUSD complete  feeLiquidity  \
# 0 30454.97161 17.15427 60873.26895        0       0.00000
# 1     0.00000  0.00000   918.06384        0       0.00000
# 2  9015.97773  5.07836 18021.00075    False       0.00000
# 3 30455.09844 17.15420 60873.19115    False       0.00000
# 4     0.00000  0.00000  2240.96036        0       0.00000
#
#                                         feeTo  \
# 0                                           0
# 1                                           0
# 2  0xe11fc0b43ab98eb91e9836129d1ee7c3bc95df50
# 3                                           0
# 4                                           0
#
#                                                   id  liquidity  logIndex  \
# 0  0xe7a6168c4cd9ac3c450c9d8299c302e2de876b49cc2d...    0.00055       267
# 1  0x90c3385fc44c9c0b6d411bba76fb622e15e00f0c5cdb...    0.00000        69
# 2  0x43cc98ca5eac49b95bd31709791277e7f622bcc92d1b...    0.00016       239
# ...

# %%
wallet1_transactions
# Out:
#         index     amount0  amount1   amountUSD complete  feeLiquidity  \
# 0          16 30454.97161 17.15427 60873.26895        0       0.00000
# 1         334     0.00000  0.00000   918.06384        0       0.00000
# 2          11  9015.97773  5.07836 18021.00075    False       0.00000
# 3          12 30455.09844 17.15420 60873.19115    False       0.00000
# 4         335     0.00000  0.00000  2240.96036        0       0.00000
# ...       ...         ...      ...         ...      ...           ...
# 429611   1082     0.00000  0.00000    22.65822        0       0.00000
# 429612   1083     0.00000  0.00000 24509.76347        0       0.00000
# 429613   1084     0.00000  0.00000  5004.85211        0       0.00000
# 429614   1085     0.00000  0.00000   251.39258        0       0.00000
# 429615   1086     0.00000  0.00000 20645.41204        0       0.00000
#
#                                              feeTo  \
# 0                                                0
# ...

# %%
# Create one DataFrame filtered to Swaps only to calculate impermanent loss 
wallet1_swapsonly = wallet1_transactions_personal_perc[wallet1_transactions_personal_perc['action_name']=='SWAP']
wallet1_swapsonly = wallet1_swapsonly.reset_index(drop=True)
wallet1_swapsonly.head(50)
wallet1_transactions
# Out:
#         index     amount0  amount1   amountUSD complete  feeLiquidity  \
# 0          16 30454.97161 17.15427 60873.26895        0       0.00000
# 1         334     0.00000  0.00000   918.06384        0       0.00000
# 2          11  9015.97773  5.07836 18021.00075    False       0.00000
# 3          12 30455.09844 17.15420 60873.19115    False       0.00000
# 4         335     0.00000  0.00000  2240.96036        0       0.00000
# ...       ...         ...      ...         ...      ...           ...
# 429611   1082     0.00000  0.00000    22.65822        0       0.00000
# 429612   1083     0.00000  0.00000 24509.76347        0       0.00000
# 429613   1084     0.00000  0.00000  5004.85211        0       0.00000
# 429614   1085     0.00000  0.00000   251.39258        0       0.00000
# 429615   1086     0.00000  0.00000 20645.41204        0       0.00000
#
#                                              feeTo  \
# 0                                                0
# ...

# %%
wallet1_impermanent_loss = calculate_impermanent_loss(df = wallet1_swapsonly, 
                                                      eth_value = 17.154272	, 
                                                      usdc_value = 30454.971614)
wallet1_impermanent_loss
# Out:
# <ipython-input-783-35d25c4d9a9d>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['impermanent_loss'][i] = impermanentLoss
# <ipython-input-783-35d25c4d9a9d>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['transaction_fee_gained'][i] = transaction_fee_gained
#         amount0  amount1    amountUSD complete  feeLiquidity feeTo  \
# 0       0.00000  0.00000    918.06384        0       0.00000     0
# 1       0.00000  0.00000   2240.96036        0       0.00000     0
# 2       0.00000  0.00000 115545.92501        0       0.00000     0
# ...

# %% [markdown]
# Calculate impermanent loss for Wallet 1

# %%
wallet1_impermanent_loss.impermanent_loss.describe()
# Out:
# count   420584.00000
# mean         0.50775
# std         17.77094
# min      -1392.84140
# 25%          1.00000
# 50%          1.00000
# 75%          1.00000
# max          1.00000
# Name: impermanent_loss, dtype: float64

# %% [markdown]
# ### Wallet 2

# %%
all_data[all_data['to'].str.contains("0x40d47cb29eb84a75f8db202910df35a7a6a1ec72", case=False)]
# Out:
#       index     amount0  amount1   amountUSD complete  feeLiquidity feeTo  \
# 1224    100 10861.61427 30.00000 21500.82428        0       0.00000     0
#
#                                                      id  liquidity  logIndex  \
# 1224  0x0086210de9c0861071e9cea48b989ae89067f0194878...    0.00047       297
#
#                                           sender           timestamp  \
# 1224  0xd9e1ce17f2641f24ae83637ab66a2cca9c378b9f 2020-09-11 03:25:08
#
#                                               to  \
# 1224  0x40d47cb29eb84a75f8db202910df35a7a6a1ec72
#
#                                          pair.id  pair.name  \
# 1224  0x397ff1542f962076d0bfe58ea045ffa2d347aca0  USDC-WETH
#
#                                          transaction.id action_name  \
# 1224  0x0086210de9c0861071e9cea48b989ae89067f0194878...        MINT
#
#       amount0In  amount0Out  amount1In  amount1Out  newly_added_usdc  \
# 1224    0.00000     0.00000    0.00000     0.00000       10861.61427
#
# ...

# %%
wallet2_transaction1_index = index[all_data['to'].str.contains("0x40d47cb29eb84a75f8db202910df35a7a6a1ec72", case=False)]
wallet2_transaction1_index = wallet2_transaction1_index.tolist()
wallet2_transaction1_index = wallet2_transaction1_index[0]
wallet2_transaction1_index
# Out:
# 1224

# %%
wallet2_transactions = all_data[wallet2_transaction1_index:]

wallet2_swapsonly = wallet2_transactions[wallet2_transactions['action_name']=='SWAP']
wallet2_swapsonly = wallet2_swapsonly.reset_index()
wallet2_swapsonly.head()
# Out:
#    level_0  index  amount0  amount1    amountUSD complete  feeLiquidity feeTo  \
# 0     1225    967  0.00000  0.00000 107455.11148        0       0.00000     0
# 1     1226    968  0.00000  0.00000   9907.68811        0       0.00000     0
# 2     1228    969  0.00000  0.00000  12588.08587        0       0.00000     0
# 3     1231    970  0.00000  0.00000   1768.86212        0       0.00000     0
# 4     1232    971  0.00000  0.00000  74258.71766        0       0.00000     0
#
#                                                   id  liquidity  logIndex  \
# 0  0x7e59821b6636ece5c40d98677cfe24ceb6c88087f467...    0.00000       114
# 1  0x995cdfe98781247e0ec8d2c93317a9749cac3b7204aa...    0.00000       287
# 2  0x0a0b2b1c161347b4b5aca94ed5355c64ccca653830de...    0.00000       260
# 3  0x3820e24d1db03617e51e873a8509d8b5e0415f67ea5d...    0.00000       154
# 4  0xf8120a62a0a377cda34eb0f9e5eef8392fc6a519243f...    0.00000       243
#
# ...

# %% [markdown]
# ### Wallet 3

# %%
all_data[all_data['to'].str.contains("0x6913a43573f51a2ab6ea238f19d6383af5a49713", case=False)]
# Out:
#       index   amount0  amount1  amountUSD complete  feeLiquidity feeTo  \
# 5652    134 800.39621  2.19504 1586.45336        0       0.00000     0
#
#                                                      id  liquidity  logIndex  \
# 5652  0x45a08e517fc7539a6bd63cdc4d66b68e4ee009d2b6af...    0.00003       267
#
#                                           sender           timestamp  \
# 5652  0xd9e1ce17f2641f24ae83637ab66a2cca9c378b9f 2020-09-14 05:33:48
#
#                                               to  \
# 5652  0x6913a43573f51a2ab6ea238f19d6383af5a49713
#
#                                          pair.id  pair.name  \
# 5652  0x397ff1542f962076d0bfe58ea045ffa2d347aca0  USDC-WETH
#
#                                          transaction.id action_name  \
# 5652  0x45a08e517fc7539a6bd63cdc4d66b68e4ee009d2b6af...        MINT
#
#       amount0In  amount0Out  amount1In  amount1Out  newly_added_usdc  \
# 5652    0.00000     0.00000    0.00000     0.00000         800.39621
#
# ...

# %%
wallet3_transaction1_index = index[all_data['to'].str.contains("0x6913a43573f51a2ab6ea238f19d6383af5a49713", case=False)]
wallet3_transaction1_index = wallet3_transaction1_index.tolist()
wallet3_transaction1_index = wallet3_transaction1_index[0]
wallet3_transaction1_index
# Out:
# 5652

# %%
wallet3_transactions = all_data[wallet3_transaction1_index:]
wallet3_transactions.head()
# Out:
#       index    amount0  amount1   amountUSD complete  feeLiquidity feeTo  \
# 5652    134  800.39621  2.19504  1586.45336        0       0.00000     0
# 5653    135 4375.66529 12.00000  8667.04510        0       0.00000     0
# 5654    799    0.00000  0.00000 13526.73710        0       0.00000     0
# 5655    136 8756.71076 24.00000 17300.57286        0       0.00000     0
# 5656    800    0.00000  0.00000 14395.40806        0       0.00000     0
#
#                                                      id  liquidity  logIndex  \
# 5652  0x45a08e517fc7539a6bd63cdc4d66b68e4ee009d2b6af...    0.00003       267
# 5653  0x08a6f57871eea65388ce77e14e0d28936c9328ce4477...    0.00019       212
# 5654  0x673512a2c12ff8397014c6c6110af9514730fde972fc...    0.00000       219
# 5655  0x902b853f9aef48c9da0ebf118bc5e332dc3a3ae2b0c0...    0.00000       123
# 5656  0x6da8c81e3c135f7619597fe58c8b0c701449b7e7c62a...    0.00000       324
#
# ...

# %% [markdown]
# # Impermanent Loss Approach 2: Net Value vs. Holding

# %% [markdown]
# We isolate our data to only include wallet addresses that had 1 burn and 1 mint in the pool. Using this subset of our data, we calcualte their overall gain/loss in USDC to examine the relationship between time spent in pool and overall amount earned.

# %% [markdown]
# ## Isolate data to only wallet addresses with 1 burn, 1 mint

# %%
mints = pd.concat(map(pd.read_csv, glob.glob('/Users/samantha/MATH446/MATH446_project/sushiswap_data/sushi_mints/*.csv')))
mints['action_name'] = 'MINT'
burns = pd.concat(map(pd.read_csv, glob.glob('/Users/samantha/MATH446/MATH446_project/sushiswap_data/sushi_burns/*.csv')))
burns['action_name'] = 'BURN'

# %%
burnmint_only = pd.concat([burns, mints])
burnmint_only.head()
# Out:
#       amount0  amount1   amountUSD complete  feeLiquidity  \
# 0    53.15560  0.01622   106.23467    False       0.00000
# 1 33429.99772 10.19956 66802.06608    False       0.00000
# 2 34128.89488 10.39662 68332.12133    False       0.00000
# 3 33034.68690 10.00513 66068.75457    False       0.00000
# 4  5096.18041  1.54499 10187.64567    False       0.00000
#
#                                         feeTo  \
# 0  0xe11fc0b43ab98eb91e9836129d1ee7c3bc95df50
# 1  0xe11fc0b43ab98eb91e9836129d1ee7c3bc95df50
# 2  0xe11fc0b43ab98eb91e9836129d1ee7c3bc95df50
# 3  0xe11fc0b43ab98eb91e9836129d1ee7c3bc95df50
# 4  0xe11fc0b43ab98eb91e9836129d1ee7c3bc95df50
#
#                                                   id  liquidity  logIndex  \
# 0  0x936805cb4d012886f76dba41af99490bbfe58090c7d9...    0.00000        18
# 1  0x40ae1f2ec9393cdf0c3dccbac0e280eba5ef0edef736...    0.00040        16
# 2  0x692c11b5a88bafe38e33ed53c9d69f2e654546c1c56a...    0.00041        46
# ...

# %%
by_wallet_sender = burnmint_only.groupby('sender').action_name.value_counts().unstack().reset_index()
by_wallet_sender.columns = ['wallet_address', 'total_burns', 'total_mints']
by_wallet_sender = by_wallet_sender.set_index('wallet_address', drop=True).drop(['total_mints'], axis=1)
by_wallet_sender.head()
# Out:
#                                             total_burns
# wallet_address
# 0x0000000000000d9054f605ca65a2647c2b521422      1.00000
# 0x0000000000007f150bd6f54c40a34d7c3d5e9f56      9.00000
# 0x0000021e9fb06e0a6cb1c238548d140b0dc258c7      1.00000
# 0x000006eee6e39015cb523aebdd4d0b1855aba682      1.00000
# 0x000f75539c2bc3941e4a29acb1d9a8254eff427f      1.00000

# %%
by_wallet_to = burnmint_only.groupby('to').action_name.value_counts().unstack().reset_index()
by_wallet_to.columns = ['wallet_address', 'total_burns', 'total_mints']
by_wallet_to = by_wallet_to.set_index('wallet_address', drop=True).drop(['total_burns'], axis=1)
by_wallet_to.head()
# Out:
#                                             total_mints
# wallet_address
# 0x005d64b3fedd6d53edf19142087d51c7ac6ba595      1.00000
# 0x00a4481a861c428c489924e721f727f1587d0fd0      1.00000
# 0x01f5a090daad0cdbaf33409da01687db0cbba353      1.00000
# 0x01f908db631d558540372f6bbc51ef0afc7d7be3      1.00000
# 0x029ce969b27513ad1868d74bebe59d82d5917e17      1.00000

# %%
total_burns_mints = by_wallet_sender.merge(by_wallet_to, how='outer', left_index=True, right_index=True)
total_burns_mints.head()
# Out:
#                                             total_burns  total_mints
# wallet_address
# 0x0000000000000d9054f605ca65a2647c2b521422      1.00000          NaN
# 0x0000000000007f150bd6f54c40a34d7c3d5e9f56      9.00000          NaN
# 0x0000021e9fb06e0a6cb1c238548d140b0dc258c7      1.00000          NaN
# 0x000006eee6e39015cb523aebdd4d0b1855aba682      1.00000          NaN
# 0x000f75539c2bc3941e4a29acb1d9a8254eff427f      1.00000          NaN

# %%
oneburnonemint = total_burns_mints[(total_burns_mints['total_burns']==1) 
                  & (total_burns_mints['total_mints']==1)]
oneburnonemint = oneburnonemint.reset_index()
oneburnonemint.head()
# Out:
#                                wallet_address  total_burns  total_mints
# 0  0x005d64b3fedd6d53edf19142087d51c7ac6ba595      1.00000      1.00000
# 1  0x01f908db631d558540372f6bbc51ef0afc7d7be3      1.00000      1.00000
# 2  0x029ce969b27513ad1868d74bebe59d82d5917e17      1.00000      1.00000
# 3  0x03086e6c6c6f446b05daeae62fe65eba1850e731      1.00000      1.00000
# 4  0x0337f1e4ef2a0835f68900e32746eb49d3d921d7      1.00000      1.00000

# %%
wallets_of_interest = oneburnonemint['wallet_address'].tolist()

# %% [markdown]
# ## Gather all data for wallets of interest

# %%
mints_of_interest = all_data.loc[all_data['to'].isin(wallets_of_interest)]
burns_of_interest = all_data.loc[all_data['sender'].isin(wallets_of_interest)]
frames_int = [burns_of_interest,mints_of_interest] # this actually unintentionally gathered all swaps too for these wallets
new_data = pd.concat(frames_int) # use same code from above to combine into one dataframe
new_data = new_data.sort_index() # sort so we have chronological order instead of mints then burns
new_data = new_data.reset_index() #gets rid of old index

# %%
burn_mints = new_data[new_data['action_name'] != 'SWAP'] # get rid of swaps
burn_mints = burn_mints.drop(['level_0', 'liquidity', 'index', 'complete', 'feeLiquidity', 'feeTo', 'id', 'logIndex', 'transaction.id', 'cum_sum_usdc', 'cum_sum_eth', 'personal_perc'], axis=1)
burn_mints = burn_mints.reset_index(drop=True)
burn_mints.head()
# Out:
#        amount0    amount1    amountUSD  \
# 0   3312.98000    8.97726   6574.95599
# 1    809.85986    2.20103   1607.19666
# 2 446779.09677 1200.00000 885185.84914
# 3    409.54751    1.10000    811.14120
# 4  20000.00000   53.74630  39612.15203
#
#                                        sender           timestamp  \
# 0  0xd9e1ce17f2641f24ae83637ab66a2cca9c378b9f 2020-09-10 07:23:23
# 1  0xd9e1ce17f2641f24ae83637ab66a2cca9c378b9f 2020-09-10 10:29:02
# 2  0xd9e1ce17f2641f24ae83637ab66a2cca9c378b9f 2020-09-10 14:39:52
# 3  0xd9e1ce17f2641f24ae83637ab66a2cca9c378b9f 2020-09-10 14:40:14
# 4  0xd9e1ce17f2641f24ae83637ab66a2cca9c378b9f 2020-09-10 14:45:27
#
#                                            to  \
# 0  0x7bd141bd5384c42a9c929711ce5dba0a74dbac99
# 1  0xa0c044688d6a9505d8250bb0be07e2a12865cfef
# 2  0x3ada347a2c817d4dae26535f817a4141bce34378
# 3  0x6addaa208ea7c6e413f0c514dc1ba7510390c500
# 4  0x432106a096c8d2afda1aa8199e408e8c10447e1a
#
# ...

# %% [markdown]
# We used this for loop to gather the data from new_data (which is grouped by transaction) into our dataframe that has information about the wallets. By generating lists for all the relevant data, and then appending it to the wallets_of_interest dataframe, we are able to have all relevant data in one place, based on wallet address.

# %%
# calculate the time in pool & actual gains
time_in_pool = []
actual_gains = []
burn_times = []
mint_times = []
mint_amount_eth = []
mint_amount_usdc = []
burn_amount_eth = []
burn_amount_usdc = []
for wallet in wallets_of_interest:
    for i in range(len(burn_mints)):
        if burn_mints['action_name'][i] != 'SWAP':
            if burn_mints['sender'][i] == wallet:
                burn_time = burn_mints['timestamp'][i]
                amount_out = burn_mints['amountUSD'][i]
                burn_times.append(burn_time)  
                eth_burned = - burn_mints['newly_added_eth'][i]
                burn_amount_eth.append(eth_burned)
                usdc_burned = - burn_mints['newly_added_usdc'][i]
                burn_amount_usdc.append(usdc_burned)
            elif burn_mints['to'][i] == wallet:
                mint_time = burn_mints['timestamp'][i]
                amount_in = burn_mints['amountUSD'][i]
                mint_times.append(mint_time)
                eth_minted = burn_mints['newly_added_eth'][i]
                mint_amount_eth.append(eth_minted)
                usdc_minted = burn_mints['newly_added_usdc'][i]
                mint_amount_usdc.append(usdc_minted)
    time_stayed = burn_time - mint_time
    time_in_pool.append(time_stayed)   
    actual_gain = amount_out - amount_in
    actual_gains.append(actual_gain)

# %%
oneburnonemint['time_in_pool'] = time_in_pool
oneburnonemint['actual_gain'] = actual_gains
oneburnonemint['mint_time'] = mint_times
oneburnonemint['burn_time'] = burn_times
oneburnonemint['eth_minted'] = mint_amount_eth
oneburnonemint['usdc_minted'] = mint_amount_usdc
oneburnonemint['eth_burned'] = burn_amount_eth
oneburnonemint['usdc_burned'] = burn_amount_usdc

# %% [markdown]
# Little bit of cleaning. We got negative amounts of time for 6 wallets, which would only be possible if some data were missing and they had more than 1 burn and/or mint in reality.

# %%
oneburnonemint = oneburnonemint[oneburnonemint['time_in_pool'] > pd.Timedelta(0)] # got a negative amount of time for 6 wallets so we remove those
oneburnonemint = oneburnonemint.reset_index(drop=True) # reset index with our remaining 282 wallets
oneburnonemint.head()
# Out:
#                                wallet_address  total_burns  total_mints  \
# 0  0x005d64b3fedd6d53edf19142087d51c7ac6ba595      1.00000      1.00000
# 1  0x01f908db631d558540372f6bbc51ef0afc7d7be3      1.00000      1.00000
# 2  0x029ce969b27513ad1868d74bebe59d82d5917e17      1.00000      1.00000
# 3  0x03086e6c6c6f446b05daeae62fe65eba1850e731      1.00000      1.00000
# 4  0x0337f1e4ef2a0835f68900e32746eb49d3d921d7      1.00000      1.00000
#
#       time_in_pool  actual_gain           mint_time           burn_time  \
# 0 21 days 00:21:14   8727.88843 2021-03-15 18:28:23 2021-04-05 18:49:37
# 1 18 days 23:13:28  32263.20129 2021-03-15 18:41:21 2021-04-03 17:54:49
# 2 13 days 21:01:17   8862.99654 2021-03-15 18:19:54 2021-03-29 15:21:11
# 3  6 days 20:47:11  -5370.12915 2020-09-15 06:05:57 2020-09-22 02:53:08
# 4 70 days 17:47:37    397.36697 2021-03-16 17:51:52 2021-05-26 11:39:29
#
#    eth_minted  usdc_minted  eth_burned  usdc_burned
# ...

# %%
# calculate the rate of eth when the mints and burns took place for each transaction
oneburnonemint['eth_rate_mint'] = oneburnonemint['usdc_minted'] / oneburnonemint['eth_minted']
oneburnonemint['eth_rate_burn'] = oneburnonemint['usdc_burned'] / oneburnonemint['eth_burned']

# %% [markdown]
# ## Data Cleaning

# %%
oneburnonemint.dtypes
# Out:
# wallet_address             object
# total_burns               float64
# total_mints               float64
# time_in_pool      timedelta64[ns]
# actual_gain               float64
# mint_time          datetime64[ns]
# burn_time          datetime64[ns]
# eth_minted                float64
# usdc_minted               float64
# eth_burned                float64
# usdc_burned               float64
# eth_rate_mint             float64
# eth_rate_burn             float64
# dtype: object

# %% [markdown]
# Create another column of `time_in_pool` expressed in days in order to perform linear regression later on

# %%
oneburnonemint['time_in_pool_days'] = oneburnonemint['time_in_pool'] / pd.to_timedelta(1, unit='D')

# %% [markdown]
# ## Calculate Impermanent Loss

# %% [markdown]
# Impermanent Loss = (value if held - value after providing liquidity) / value if held <br>
# Impermanent Loss = ((eth_minted * new_eth_rate + usdc_minted) - (eth_burned * new_eth_rate + usdc_burned)) / (eth_minted * new_eth_rate + usdc_minted)

# %%
oneburnonemint['impermanent_loss'] = ((oneburnonemint['eth_minted']*oneburnonemint['eth_rate_burn'] + oneburnonemint['usdc_minted']) - \
                                      (oneburnonemint['eth_burned']*oneburnonemint['eth_rate_burn'] + oneburnonemint['usdc_burned'])) / \
                                    (oneburnonemint['eth_minted']*oneburnonemint['eth_rate_burn'] + oneburnonemint['usdc_minted'])

# %%
#calculated the hold value and liquidity value separately to double check our data
oneburnonemint['hold_value'] = oneburnonemint['eth_minted']*oneburnonemint['eth_rate_burn'] + oneburnonemint['usdc_minted']
oneburnonemint['liq_value'] = oneburnonemint['eth_burned']*oneburnonemint['eth_rate_burn'] + oneburnonemint['usdc_burned']

# %%
oneburnonemint['impermanent_loss'].describe()
# Out:
# count    282.00000
# mean      -3.19485
# std       27.79397
# min     -324.52988
# 25%       -0.00749
# 50%       -0.00065
# 75%       -0.00003
# max        0.40097
# Name: impermanent_loss, dtype: float64

# %% [markdown]
# Clearly not the result we were expecting. Impermanent loss should be positive because we are subtracting liquidity value from value if held. Even below, where we look at impermanent loss among wallets who burned less ETH than they minted, most of them made money.

# %%
oneburnonemint.loc[oneburnonemint['eth_burned'] \
                        < oneburnonemint['eth_minted']]['impermanent_loss'].describe()
# Out:
# count   164.00000
# mean      0.00176
# std       0.04120
# min      -0.10310
# 25%      -0.00495
# 50%      -0.00027
# 75%      -0.00001
# max       0.40097
# Name: impermanent_loss, dtype: float64

# %% [markdown]
# At this point, we realized that the BURN amounts also had the amount of fees that the liquidity provider had earned included. This means that when we see a negative number in our "impermanent loss" column, that indicates that the wallet address beat the market by providing liquidity.

# %%
len(oneburnonemint.loc[oneburnonemint['impermanent_loss'] > 0])
# Out:
# 41

# %% [markdown]
# only 41 wallets lost money by providing liquidity

# %% [markdown]
# ## Calculate rate change

# %%
oneburnonemint['rate_change'] = oneburnonemint['eth_rate_burn'] - oneburnonemint['eth_rate_mint']
oneburnonemint.head()
# Out:
#                                wallet_address  total_burns  total_mints  \
# 0  0x005d64b3fedd6d53edf19142087d51c7ac6ba595      1.00000      1.00000
# 1  0x01f908db631d558540372f6bbc51ef0afc7d7be3      1.00000      1.00000
# 2  0x029ce969b27513ad1868d74bebe59d82d5917e17      1.00000      1.00000
# 3  0x03086e6c6c6f446b05daeae62fe65eba1850e731      1.00000      1.00000
# 4  0x0337f1e4ef2a0835f68900e32746eb49d3d921d7      1.00000      1.00000
#
#       time_in_pool  actual_gain           mint_time           burn_time  \
# 0 21 days 00:21:14   8727.88843 2021-03-15 18:28:23 2021-04-05 18:49:37
# 1 18 days 23:13:28  32263.20129 2021-03-15 18:41:21 2021-04-03 17:54:49
# 2 13 days 21:01:17   8862.99654 2021-03-15 18:19:54 2021-03-29 15:21:11
# 3  6 days 20:47:11  -5370.12915 2020-09-15 06:05:57 2020-09-22 02:53:08
# 4 70 days 17:47:37    397.36697 2021-03-16 17:51:52 2021-05-26 11:39:29
#
#    eth_minted  usdc_minted  eth_burned  usdc_burned  eth_rate_mint  \
# ...

# %% [markdown]
# # Ethereum MacroData

# %% [markdown]
# We define a new metric, Net Value vs. Holding, as impermanent loss when taking liquidity into account: <br>
# Net value vs. holding = Impermanent Loss - Transaction fees gained as liquidity provider

# %% [markdown]
# ## Data Collection

# %% [markdown]
# Collect additional data on market conditions of Ethereum, such as historic price and volatility <br> INSERT SOURCES HERE

# %%
eth_vol = pd.read_csv('/Users/samantha/MATH446/MATH446_project/random_data/eth_features/ethvol.csv')
eth_price = pd.read_csv('/Users/samantha/MATH446/MATH446_project/random_data/eth_features/ethprice.csv')

# %%
masterdf = oneburnonemint.copy()

# %%
iv = []
for i in eth_vol['Ethereum Volatility Index']:
    impliedmove = i* np.sqrt((1/365)) * np.sqrt((2/np.pi))
    iv.append(impliedmove)
eth_vol['Daily_Implied_Move'] = iv
eth_vol.head()
# Out:
#                   Date  Ethereum Volatility Index  Daily_Implied_Move
# 0  2020-04-15 00:00:00                  105.48000             4.40518
# 1  2020-04-16 00:00:00                  103.27000             4.31288
# 2  2020-04-17 00:00:00                  102.55000             4.28281
# 3  2020-04-18 00:00:00                   99.87000             4.17089
# 4  2020-04-19 00:00:00                  101.69000             4.24690

# %%
masterdf['mint_time'] = pd.to_datetime(masterdf['mint_time'])
masterdf['burn_time'] = pd.to_datetime(masterdf['burn_time'])
eth_vol['Date'] =  pd.to_datetime(eth_vol['Date'])

# %%
masterdf.head()
# Out:
#                                wallet_address  total_burns  total_mints  \
# 0  0x005d64b3fedd6d53edf19142087d51c7ac6ba595      1.00000      1.00000
# 1  0x01f908db631d558540372f6bbc51ef0afc7d7be3      1.00000      1.00000
# 2  0x029ce969b27513ad1868d74bebe59d82d5917e17      1.00000      1.00000
# 3  0x03086e6c6c6f446b05daeae62fe65eba1850e731      1.00000      1.00000
# 4  0x0337f1e4ef2a0835f68900e32746eb49d3d921d7      1.00000      1.00000
#
#       time_in_pool  actual_gain           mint_time           burn_time  \
# 0 21 days 00:21:14   8727.88843 2021-03-15 18:28:23 2021-04-05 18:49:37
# 1 18 days 23:13:28  32263.20129 2021-03-15 18:41:21 2021-04-03 17:54:49
# 2 13 days 21:01:17   8862.99654 2021-03-15 18:19:54 2021-03-29 15:21:11
# 3  6 days 20:47:11  -5370.12915 2020-09-15 06:05:57 2020-09-22 02:53:08
# 4 70 days 17:47:37    397.36697 2021-03-16 17:51:52 2021-05-26 11:39:29
#
#    eth_minted  usdc_minted  eth_burned  usdc_burned  eth_rate_mint  \
# ...

# %%
listofmintvols = []
ethvolidx = 0
mintidx = 0
iters = 0
masterdf['mint_vol'] = 0

for j in eth_vol['Date']:
    ethvolidx += 1
    mintvolidx = 0
    for i in masterdf['mint_time']:
        mintvolidx += 1
        if(i.year == j.year and i.dayofyear == j.dayofyear):
            masterdf['mint_vol'][mintvolidx-1] = eth_vol['Daily_Implied_Move'][ethvolidx-1]
            #print(wallets['mint_vol'][mintvolidx-1])
            #print(eth_vol['Daily_Implied_Move'][ethvolidx-1])
            #print(eth_vol['Daily_Implied_Move'][ethvolidx-1])
            #listofmintvols.append(eth_vol['Daily_Implied_Move'][mintvolidx-1])
            #print(mintvolidx)
            iters+=1
            
for i in masterdf['mint_time']:
    mintvolidx+=1
    ethvolidx = 0
    for j in eth_vol['Date']:
        ethvolidx += 1
        if(i.year == j.year and i.dayofyear == j.dayofyear):
            listofmintvols.append(eth_vol['Daily_Implied_Move'][ethvolidx-1])
            #wallets['mint_vol'][mintvolidx-1] = eth_vol['Daily_Implied_Move'][ethvolidx-1]
            

len(listofmintvols)
# Out:
# <ipython-input-831-9c7977f08b08>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   masterdf['mint_vol'][mintvolidx-1] = eth_vol['Daily_Implied_Move'][ethvolidx-1]
# 282

# %%
listofmintvols = []
ethvolidx = 0
mintidx = 0
iters = 0

for i in masterdf['mint_time']:
    mintvolidx+=1
    ethvolidx = 0
    for j in eth_vol['Date']:
        ethvolidx += 1
        if(i.year == j.year and i.dayofyear == j.dayofyear):
            listofmintvols.append(eth_vol['Daily_Implied_Move'][ethvolidx-1])
            #wallets['mint_vol'][mintvolidx-1] = eth_vol['Daily_Implied_Move'][ethvolidx-1]
            
len(listofmintvols)
# Out:
# 282

# %%
listofburnvols = []
ethvolidx = 0
burnvolidx = 0
iters = 0

for i in masterdf['burn_time']:
    burnvolidx+=1
    ethvolidx = 0
    for j in eth_vol['Date']:
        ethvolidx += 1
        if(i.year == j.year and i.dayofyear == j.dayofyear):
            listofburnvols.append(eth_vol['Daily_Implied_Move'][ethvolidx-1])
            #wallets['mint_vol'][mintvolidx-1] = eth_vol['Daily_Implied_Move'][ethvolidx-1]
            
len(listofburnvols)
# Out:
# 282

# %%
masterdf['mint_vol'] = listofmintvols
masterdf['burn_vol'] = listofburnvols

# %%
eth_price = eth_price.iloc[::-1]

# %%
eth_price['Date'] = pd.date_range(start='9/10/2020', periods=len(eth_price), freq='D')

# %%
listofburnvols = []
ethvolidx = 0
burnvolidx = 0
iters = 0

for i in masterdf['burn_time']:
    burnvolidx+=1
    ethvolidx = 0
    for j in eth_vol['Date']:
        ethvolidx += 1
        if(i.year == j.year and i.dayofyear == j.dayofyear):
            listofburnvols.append(eth_vol['Daily_Implied_Move'][ethvolidx-1])
            #wallets['mint_vol'][mintvolidx-1] = eth_vol['Daily_Implied_Move'][ethvolidx-1]
            
len(listofburnvols)
# Out:
# 282

# %%
newdf = eth_price.reset_index()

# %%
listofburnprice = []
ethvolidx = 0
burnprice = 0
iters = 0

for i in masterdf['burn_time']:
    burnvolidx+=1
    ethvolidx = 0
    for j in newdf['Date']:
        ethvolidx += 1
        if(i.year == j.year and i.dayofyear == j.dayofyear):
            listofburnprice.append(newdf['Price'][ethvolidx-1])
            #wallets['mint_vol'][mintvolidx-1] = eth_vol['Daily_Implied_Move'][ethvolidx-1]
            
len(listofburnprice)
# Out:
# 282

# %%
masterdf['Burn_Price'] = listofburnprice

# %%
listofmintprice = []
ethvolidx = 0
burnprice = 0
iters = 0
burnvolidx = 0

for i in masterdf['mint_time']:
    burnvolidx+=1
    ethvolidx = 0
    for j in newdf['Date']:
        ethvolidx += 1
        if(i.year == j.year and i.dayofyear == j.dayofyear):
            listofmintprice.append(newdf['Price'][ethvolidx-1])
            #wallets['mint_vol'][mintvolidx-1] = eth_vol['Daily_Implied_Move'][ethvolidx-1]
            
len(listofmintprice)
masterdf['Mint_Price'] = listofmintprice

# %%
listofvolumeburn = []
ethvolidx = 0
burnprice = 0
iters = 0
burnvolidx = 0

for i in masterdf['burn_time']:
    burnvolidx+=1
    ethvolidx = 0
    for j in newdf['Date']:
        ethvolidx += 1
        if(i.year == j.year and i.dayofyear == j.dayofyear):
            listofvolumeburn.append(newdf['Vol.'][ethvolidx-1])
            #wallets['mint_vol'][mintvolidx-1] = eth_vol['Daily_Implied_Move'][ethvolidx-1]
            
len(listofvolumeburn)
listofvolumeburn
masterdf['Burn_Volume'] = listofvolumeburn

# %%
listofvolumeburn = []
ethvolidx = 0
burnprice = 0
iters = 0
burnvolidx = 0

for i in masterdf['mint_time']:
    burnvolidx+=1
    ethvolidx = 0
    for j in newdf['Date']:
        ethvolidx += 1
        if(i.year == j.year and i.dayofyear == j.dayofyear):
            listofvolumeburn.append(newdf['Vol.'][ethvolidx-1])
            #wallets['mint_vol'][mintvolidx-1] = eth_vol['Daily_Implied_Move'][ethvolidx-1]
            
len(listofvolumeburn)
masterdf['Mint_Volume'] = listofvolumeburn

# %%
listofvolumeburn = []
ethvolidx = 0
burnprice = 0
iters = 0
burnvolidx = 0

for i in masterdf['mint_time']:
    burnvolidx+=1
    ethvolidx = 0
    for j in newdf['Date']:
        ethvolidx += 1
        if(i.year == j.year and i.dayofyear == j.dayofyear):
            listofvolumeburn.append(newdf['Change %'][ethvolidx-1])
            #wallets['mint_vol'][mintvolidx-1] = eth_vol['Daily_Implied_Move'][ethvolidx-1]
            
len(listofvolumeburn)
masterdf['Mint_PerChange'] = listofvolumeburn

# %%
listofvolumeburn = []
ethvolidx = 0
burnprice = 0
iters = 0
burnvolidx = 0

for i in masterdf['burn_time']:
    burnvolidx+=1
    ethvolidx = 0
    for j in newdf['Date']:
        ethvolidx += 1
        if(i.year == j.year and i.dayofyear == j.dayofyear):
            listofvolumeburn.append(newdf['Change %'][ethvolidx-1])
            #wallets['mint_vol'][mintvolidx-1] = eth_vol['Daily_Implied_Move'][ethvolidx-1]
            
len(listofvolumeburn)
masterdf['Burn_PerChange'] = listofvolumeburn

# %% [markdown]
# ## Data Cleaning

# %%
masterdf.head()
# Out:
#                                wallet_address  total_burns  total_mints  \
# 0  0x005d64b3fedd6d53edf19142087d51c7ac6ba595      1.00000      1.00000
# 1  0x01f908db631d558540372f6bbc51ef0afc7d7be3      1.00000      1.00000
# 2  0x029ce969b27513ad1868d74bebe59d82d5917e17      1.00000      1.00000
# 3  0x03086e6c6c6f446b05daeae62fe65eba1850e731      1.00000      1.00000
# 4  0x0337f1e4ef2a0835f68900e32746eb49d3d921d7      1.00000      1.00000
#
#       time_in_pool  actual_gain           mint_time           burn_time  \
# 0 21 days 00:21:14   8727.88843 2021-03-15 18:28:23 2021-04-05 18:49:37
# 1 18 days 23:13:28  32263.20129 2021-03-15 18:41:21 2021-04-03 17:54:49
# 2 13 days 21:01:17   8862.99654 2021-03-15 18:19:54 2021-03-29 15:21:11
# 3  6 days 20:47:11  -5370.12915 2020-09-15 06:05:57 2020-09-22 02:53:08
# 4 70 days 17:47:37    397.36697 2021-03-16 17:51:52 2021-05-26 11:39:29
#
#    eth_minted  usdc_minted  eth_burned  usdc_burned  eth_rate_mint  \
# ...

# %%
#calculate NVH as a percentage
masterdf['net_value_vs_holding_percentage'] = (-1*masterdf['impermanent_loss'])*100

# calculate NVH as a total dollar amount
masterdf['net_value_vs_holding_raw'] = masterdf['liq_value'] - masterdf['hold_value']

masterdf['gain_as_percentage'] = (100*masterdf['actual_gain']) /\
                        (masterdf['eth_minted']*masterdf['eth_rate_mint'] + masterdf['usdc_minted'])

# convert datetime to int
masterdf['time_in_pool_days'] = masterdf['time_in_pool'] / pd.to_timedelta(1, unit='D')

# %%
masterdf = masterdf.drop(['total_burns','total_mints','impermanent_loss'],axis=1)

# %%
# Clean number formatting 
masterdf['Burn_Price']=masterdf['Burn_Price'].str.replace(',','').astype(float)
masterdf['Mint_Price']=masterdf['Mint_Price'].str.replace(',','').astype(float)
masterdf['Mint_PerChange']=masterdf['Mint_PerChange'].str.replace('%','').astype(float)
masterdf['Burn_PerChange']=masterdf['Burn_PerChange'].str.replace('%','').astype(float)
masterdf['Mint_PerChange']=masterdf['Mint_PerChange'] / 100
masterdf['Burn_PerChange']=masterdf['Burn_PerChange'] / 100
masterdf.Burn_Volume = (masterdf.Burn_Volume.replace(r'[KM]+$', '', regex=True).astype(float) * \
           masterdf.Burn_Volume.str.extract(r'[\d\.]+([KM]+)', expand=False)
             .fillna(1)
            .replace(['K','M'], [10**3, 10**6]).astype(int))
masterdf.Mint_Volume = (masterdf.Mint_Volume.replace(r'[KM]+$', '', regex=True).astype(float) * \
           masterdf.Mint_Volume.str.extract(r'[\d\.]+([KM]+)', expand=False)
             .fillna(1)
            .replace(['K','M'], [10**3, 10**6]).astype(int))

# %%
masterdf.head()
# Out:
#                                wallet_address     time_in_pool  actual_gain  \
# 0  0x005d64b3fedd6d53edf19142087d51c7ac6ba595 21 days 00:21:14   8727.88843
# 1  0x01f908db631d558540372f6bbc51ef0afc7d7be3 18 days 23:13:28  32263.20129
# 2  0x029ce969b27513ad1868d74bebe59d82d5917e17 13 days 21:01:17   8862.99654
# 3  0x03086e6c6c6f446b05daeae62fe65eba1850e731  6 days 20:47:11  -5370.12915
# 4  0x0337f1e4ef2a0835f68900e32746eb49d3d921d7 70 days 17:47:37    397.36697
#
#             mint_time           burn_time  eth_minted  usdc_minted  \
# 0 2021-03-15 18:28:23 2021-04-05 18:49:37    24.97690  44328.96112
# 1 2021-03-15 18:41:21 2021-04-03 17:54:49     6.00441  10672.61340
# 2 2021-03-15 18:19:54 2021-03-29 15:21:11   300.00000 531107.17924
# 3 2020-09-15 06:05:57 2020-09-22 02:53:08   274.95542 103062.83411
# 4 2021-03-16 17:51:52 2021-05-26 11:39:29     0.28828    510.00000
#
#    eth_burned  usdc_burned  eth_rate_mint  eth_rate_burn  time_in_pool_days  \
# ...

# %%
masterdf.columns
# Out:
# Index(['wallet_address', 'time_in_pool', 'actual_gain', 'mint_time',
#        'burn_time', 'eth_minted', 'usdc_minted', 'eth_burned', 'usdc_burned',
#        'eth_rate_mint', 'eth_rate_burn', 'time_in_pool_days', 'hold_value',
#        'liq_value', 'rate_change', 'mint_vol', 'burn_vol', 'Burn_Price',
#        'Mint_Price', 'Burn_Volume', 'Mint_Volume', 'Mint_PerChange',
#        'Burn_PerChange', 'net_value_vs_holding_percentage',
#        'net_value_vs_holding_raw', 'gain_as_percentage'],
#       dtype='object')

# %% [markdown]
# # Exploratory Data Analysis on NVH

# %%
masterdf.describe()
# Out:
#                      time_in_pool    actual_gain  eth_minted    usdc_minted  \
# count                         282      282.00000   282.00000      282.00000
# mean   19 days 17:58:18.088652482    56134.64136   137.39505    96965.96924
# std    40 days 16:20:35.202732944   402300.01712   511.23731   735157.14221
# min               0 days 00:02:10 -1488241.17935     0.03000       18.53751
# 25%        0 days 18:01:23.750000        1.84341     1.99929     1708.75261
# 50%               3 days 03:41:37      275.01051    11.44356     7342.93219
# 75%       19 days 21:00:26.750000     4038.84204    53.96990    29347.19278
# max             242 days 16:20:27  4397719.19820  6566.45928 12113114.05300
#
#        eth_burned    usdc_burned  eth_rate_mint  eth_rate_burn  \
# count   282.00000      282.00000      282.00000      282.00000
# mean    193.32738   125162.82414      946.06940     1165.25787
# std     719.15769   726311.89165      714.04088      988.89374
# ...

# %%
masterdf.plot(x='eth_burned',y='net_value_vs_holding_percentage',kind='scatter')
# Out:
# <AxesSubplot:xlabel='eth_burned', ylabel='net_value_vs_holding_percentage'>

# %% [markdown]
# ## Statistical Distributions

# %%
def quartile_analysis(num_quartiles):
    quartile_temp_df = masterdf.copy()
    quartile_temp_df['y_quartile'] = pd.qcut(quartile_temp_df['net_value_vs_holding_percentage'], 
                                             num_quartiles, labels=range(num_quartiles))
    grouped_quartile_df = quartile_temp_df.groupby('y_quartile').mean()
    grouped_quartile_df = grouped_quartile_df.reset_index()
    print(grouped_quartile_df.corr().net_value_vs_holding_percentage)
    
    grouped_quartile_df.plot(x='eth_rate_burn',y='y_quartile',kind='scatter')
    grouped_quartile_df.plot(x='eth_burned',y='y_quartile',kind='scatter')

# %%
quartile_analysis(10)
# Out:
# actual_gain                        0.96727
# eth_minted                        -0.43628
# usdc_minted                       -0.22976
# eth_burned                         0.86153
# usdc_burned                        0.32879
# eth_rate_mint                      0.05543
# eth_rate_burn                      0.09861
# time_in_pool_days                  0.23712
# hold_value                        -0.24060
# liq_value                          0.32879
# rate_change                        0.13535
# mint_vol                           0.22695
# burn_vol                           0.04161
# Burn_Price                         0.09407
# Mint_Price                         0.05601
# Burn_Volume                       -0.07969
# Mint_Volume                        0.10772
# Mint_PerChange                     0.44962
# Burn_PerChange                    -0.64221
# net_value_vs_holding_percentage    1.00000
# net_value_vs_holding_raw           0.99661
# gain_as_percentage                 0.99991
# ...

# %%
quartile_analysis(50)
# Out:
# actual_gain                        0.90534
# eth_minted                        -0.07623
# usdc_minted                       -0.04437
# eth_burned                         0.75600
# usdc_burned                        0.31134
# eth_rate_mint                     -0.12557
# eth_rate_burn                     -0.10401
# time_in_pool_days                 -0.05515
# hold_value                        -0.04851
# liq_value                          0.31134
# rate_change                       -0.03724
# mint_vol                          -0.04658
# burn_vol                          -0.09857
# Burn_Price                        -0.10665
# Mint_Price                        -0.12209
# Burn_Volume                        0.06847
# Mint_Volume                        0.08947
# Mint_PerChange                     0.15210
# Burn_PerChange                    -0.22675
# net_value_vs_holding_percentage    1.00000
# net_value_vs_holding_raw           0.94181
# gain_as_percentage                 0.99992
# ...

# %%
quartile_analysis(20)
# Out:
# actual_gain                        0.97192
# eth_minted                        -0.17229
# usdc_minted                       -0.10160
# eth_burned                         0.83777
# usdc_burned                        0.37538
# eth_rate_mint                     -0.08767
# eth_rate_burn                     -0.04500
# time_in_pool_days                  0.13232
# hold_value                        -0.11168
# liq_value                          0.37538
# rate_change                        0.01590
# mint_vol                           0.00532
# burn_vol                          -0.13325
# Burn_Price                        -0.04095
# Mint_Price                        -0.07975
# Burn_Volume                       -0.00628
# Mint_Volume                        0.19082
# Mint_PerChange                     0.38999
# Burn_PerChange                    -0.11058
# net_value_vs_holding_percentage    1.00000
# net_value_vs_holding_raw           0.99704
# gain_as_percentage                 0.99991
# ...

# %% [markdown]
# ## Approach 1: Group by quantile

# %%
masterdf['y_q'] = pd.qcut(masterdf['net_value_vs_holding_percentage'], 20, labels=range(20))

# %%
gdf = masterdf.groupby('y_q').mean()
gdf = gdf.reset_index()

# %%
gdf.head()
# Out:
#   y_q   actual_gain  eth_minted  usdc_minted  eth_burned  usdc_burned  \
# 0   0   47689.83994    37.88439  20633.77124    21.33044  44472.64777
# 1   1 -100674.43279   497.41244 890325.31860   528.61151 840707.70669
# 2   2    3728.77709   313.85027 135445.91840   309.75524 137279.69796
# 3   3      18.97992    37.91545  18258.61731    37.87713  18275.09091
# 4   4     527.93551   304.03321 109576.40722   303.20180 109883.24665
#
#    eth_rate_mint  eth_rate_burn  time_in_pool_days    hold_value  \
# 0      999.05976     2483.57815           85.69021  106004.92899
# 1     1153.97452     1214.42512            7.40983 1681933.41516
# 2      841.65178      863.85773            1.36671  274574.23964
# 3      935.09853      935.63225            0.01507   36550.06367
# 4      476.53828      477.72311            0.07677  219762.60165
#
#       liq_value  rate_change  mint_vol  burn_vol  Burn_Price  Mint_Price  \
# 0   88945.29554   1484.51840   4.49801   5.74862  2514.62533  1008.96067
# ...

# %%
gdf.eth_rate_mint.plot()
# Out:
# <AxesSubplot:>

# %%
# can do classification problem on y_q rather than regression problem on y
gdf.corr().net_value_vs_holding_percentage
# Out:
# actual_gain                        0.97192
# eth_minted                        -0.17229
# usdc_minted                       -0.10160
# eth_burned                         0.83777
# usdc_burned                        0.37538
# eth_rate_mint                     -0.08767
# eth_rate_burn                     -0.04500
# time_in_pool_days                  0.13232
# hold_value                        -0.11168
# liq_value                          0.37538
# rate_change                        0.01590
# mint_vol                           0.00532
# burn_vol                          -0.13325
# Burn_Price                        -0.04095
# Mint_Price                        -0.07975
# Burn_Volume                       -0.00628
# Mint_Volume                        0.19082
# Mint_PerChange                     0.38999
# Burn_PerChange                    -0.11058
# net_value_vs_holding_percentage    1.00000
# net_value_vs_holding_raw           0.99704
# gain_as_percentage                 0.99991
# ...

# %%
gdf.plot(x='eth_rate_burn',y='y_q',kind='scatter')
# Out:
# <AxesSubplot:xlabel='eth_rate_burn', ylabel='y_q'>

# %%
gdf.plot(x='eth_burned',y='y_q',kind='scatter')
# Out:
# <AxesSubplot:xlabel='eth_burned', ylabel='y_q'>

# %%
gdf.plot(x='eth_burned',y='y_q',kind='scatter')
# Out:
# <AxesSubplot:xlabel='eth_burned', ylabel='y_q'>

# %% [markdown]
# ## Approach 2: Remove outliers

# %%
df = masterdf[masterdf.net_value_vs_holding_percentage < masterdf.net_value_vs_holding_percentage.quantile(0.85)]
df = df[df.net_value_vs_holding_percentage > df.net_value_vs_holding_percentage.quantile(.15)]
df.plot(x='eth_rate_mint',y='net_value_vs_holding_percentage',kind='scatter')
# Out:
# <AxesSubplot:xlabel='eth_rate_mint', ylabel='net_value_vs_holding_percentage'>

# %%
df.plot(x='eth_burned',y='net_value_vs_holding_percentage',kind='scatter')
# Out:
# <AxesSubplot:xlabel='eth_burned', ylabel='net_value_vs_holding_percentage'>

# %%
df.plot(x='eth_rate_burn',y='net_value_vs_holding_percentage',kind='scatter')
# Out:
# <AxesSubplot:xlabel='eth_rate_burn', ylabel='net_value_vs_holding_percentage'>

# %% [markdown]
# ## Correlation with other features

# %% [markdown]
# ### Relationship with time_in_pool_days

# %%
df.plot(x='time_in_pool_days',y='y_q',kind='scatter')
plt.title('Relationship between time spent in pool and NVVH quantile value')
plt.xlabel('time spent in pool (unit: day)')
plt.ylabel('NVVH quantile')
# Out:
# Text(0, 0.5, 'NVVH quantile')

# %% [markdown]
# Most people stays in the pool for less than 50 days, and there is a non-linear relationship between NVVH and time in pool. </br>
# NVVH is relatively high for staying longer in the pool, even though there's no obvious direct cause-and-effect relationship (not necessarily means stay longer can lead to more net gains). </br>

# %%
df['time_q'] = pd.qcut(df['time_in_pool_days'], 20, labels=range(20)) # divide time into quantiles
df.plot(x='time_q',y='y_q',kind='scatter')
plt.title('Relationship between time spent in pool quantile and NVVH quantile value')
plt.xlabel('time spent in pool (quantile scalue)')
plt.ylabel('NVVH quantile')
# Out:
# Text(0, 0.5, 'NVVH quantile')

# %% [markdown]
# Reducing the continuous data into quantiles, a higher correlation is discovered. </br>
# Reasons casuing this relationship may be: </br>
#     - staying longer in the pool do affect final net gain (potentially more transaction fee gained throughout the process) </br>
#     - our sample size is relatively small </br>
# In general, we infer that liquidity provider who stays longer in the pool may be more familiar with the liquidity behavior, thus burning at the relatively good timings. </br>

# %% [markdown]
# ### Relationship with eth_rate_burn

# %%
df.plot(x='eth_rate_burn',y='y_q',kind='scatter')
plt.title('Relationship between ETH to USDC rate at burn and NVVH quantile value')
plt.xlabel('ETH to USDC Rate when burn (how much USDC 1 ETH worth)')
plt.ylabel('NVVH quantile')
# Out:
# Text(0, 0.5, 'NVVH quantile')

# %% [markdown]
# Higher ETH to USDC rate at burn time indicates some relationship to net value especially when rate is greater than 2000 </br>
# ETH rate fluctuates around 500 - 2000 most of the time, so burning when ETH rate is higher when lead to a higher NVVH </br>

# %%
df.plot(x='eth_rate_burn',y='net_value_vs_holding_percentage',kind='scatter')
plt.title('Relationship between ETH to USDC rate at burn and NVVH value')
plt.xlabel('ETH to USDC Rate when burn (how much USDC 1 ETH worth)')
plt.ylabel('NVVH')
# Out:
# Text(0, 0.5, 'NVVH')

# %%
df_temp = df[df.eth_rate_burn > 2000]

# %%
df_temp.time_in_pool_days.describe()
# Out:
# count    45.00000
# mean     39.61540
# std      47.89449
# min       0.00649
# 25%      19.36115
# 50%      21.51933
# 75%      45.04880
# max     238.72169
# Name: time_in_pool_days, dtype: float64

# %% [markdown]
# ### Relationship with eth_rate_mint

# %%
df.plot(x='eth_rate_mint',y='y_q',kind='scatter')
plt.title('Relationship between ETH to USDC rate at mint and NVVH value')
plt.xlabel('ETH to USDC Rate when mint (how much USDC 1 ETH worth)')
plt.ylabel('NVVH')
# Out:
# Text(0, 0.5, 'NVVH')

# %%
df_temp = df[df.eth_rate_mint > 2000]
df_temp.time_in_pool_days.describe()
# Out:
# count    8.00000
# mean    14.06418
# std     24.13046
# min      0.00649
# 25%      1.88145
# 50%      3.85990
# 75%     11.37730
# max     70.95253
# Name: time_in_pool_days, dtype: float64

# %% [markdown]
# Higher mint ETH to USDC rate means higher risk but may lead to higher gain

# %% [markdown]
# ### Relationship with usdc_burned v.s. eth_burned

# %%
df.plot(x='eth_burned',y='y_q',kind='scatter')
# Out:
# <AxesSubplot:xlabel='eth_burned', ylabel='y_q'>

# %%
df.plot(x='usdc_burned',y='y_q',kind='scatter')
# Out:
# <AxesSubplot:xlabel='usdc_burned', ylabel='y_q'>

# %% [markdown]
# In general, the amount you burned is not correlated with the net gain you get </br>
# According to the correlation, usdc_burned is more correlated to the net_value_vs_holding_percentage than eth_burned </br>
# This is caused by the fact that usdc (being less worthy) has more variance than eth, which makes it a somehow better indicator for influences on NVVH, and it may be better at magnify the correlation </br>

# %% [markdown]
# ### Relationship with mint_vol and burn_vol (volatility)

# %%
df['mint_vol_q'] = pd.qcut(df['mint_vol'], 20, labels=range(13), duplicates='drop') 
df.plot(x='mint_vol_q',y='y_q',kind='scatter')
# Out:
# <AxesSubplot:xlabel='mint_vol_q', ylabel='y_q'>

# %%
gdf_with_clean = df.groupby('y_q').mean() # cleaned frame
gdf_with_clean = gdf_with_clean.reset_index()
gdf_with_clean.corr().net_value_vs_holding_percentage
# Out:
# actual_gain                        0.89832
# eth_minted                        -0.30938
# usdc_minted                        0.22012
# eth_burned                        -0.33878
# usdc_burned                        0.50819
# eth_rate_mint                      0.69183
# eth_rate_burn                      0.79615
# time_in_pool_days                  0.98968
# hold_value                         0.49150
# liq_value                          0.50819
# rate_change                        0.87541
# mint_vol                           0.73554
# burn_vol                           0.24083
# Burn_Price                         0.79080
# Mint_Price                         0.68947
# Burn_Volume                       -0.66460
# Mint_Volume                       -0.63861
# Mint_PerChange                    -0.48546
# Burn_PerChange                    -0.03485
# net_value_vs_holding_percentage    1.00000
# net_value_vs_holding_raw           0.91081
# gain_as_percentage                 0.93595
# ...

# %%
gdf_with_clean.plot(x='mint_vol',y='y_q',kind='scatter')
plt.title('Relationship between mint volatility and NVVH value')
plt.xlabel('mint volatility')
plt.ylabel('NVVH')
# Out:
# Text(0, 0.5, 'NVVH')

# %% [markdown]
# mint volatility is to some extent relate to NVVH, even though we don't have strong evidence to support the conclusion (the data size is small) </br>

# %%
df_temp = df[df.mint_vol > 4.8]
df_temp.time_in_pool_days.describe()
# Out:
# count    74.00000
# mean     22.83783
# std      32.63160
# min       0.00150
# 25%       2.89165
# 50%      17.17707
# 75%      27.49842
# max     234.62662
# Name: time_in_pool_days, dtype: float64

# %%
gdf_with_clean.plot(x='burn_vol',y='y_q',kind='scatter')
# Out:
# <AxesSubplot:xlabel='burn_vol', ylabel='y_q'>

# %% [markdown]
# burn volatility seems to have no obvious relationship to NVVH. The higher volatility leads to a less stable and less predictable market. </br>

# %% [markdown]
# # Machine Learning on NVH

# %% [markdown]
# ## Linear regression

# %% [markdown]
# To get started, run a linear regression with every single possible feature in order to see which features have the most weight

# %% [markdown]
# ### Linear Regression for Burn-Related Features Only

# %%
X_burn = masterdf[['time_in_pool_days', 'eth_rate_burn', 'burn_vol', 
                   'Burn_Price', 'Burn_Volume', 'Burn_PerChange']].to_numpy()

# %%
y_burn = masterdf['net_value_vs_holding_percentage'].to_numpy().reshape(-1,1)

# %%
reg = LinearRegression().fit(X_burn, y_burn)

# %%
reg.score(X_burn,y_burn)
# Out:
# 0.0016152656729770953

# %%
reg.coef_
# Out:
# array([[-6.99020205e-01,  3.22195565e-01,  2.58359788e+00,
#         -4.18367719e-01, -2.41616289e-05, -9.30188475e+02]])

# %%
reg.intercept_
# Out:
# array([595.08970162])

# %% [markdown]
# ### Linear Regression for Mint-Related Features Only

# %%
X_mint = masterdf[['time_in_pool_days', 'eth_rate_mint', 'mint_vol', 'Mint_Price',
       'Mint_Volume', 'Mint_PerChange']]

# %%
y_mint = masterdf['net_value_vs_holding_percentage'].to_numpy().reshape(-1,1)

# %%
reg = LinearRegression().fit(X_mint, y_mint)

# %%
reg.score(X_burn,y_burn)
# Out:
# -0.030569699310026177

# %%
reg.coef_
# Out:
# array([[-1.26518514e+00, -1.83769506e+00,  3.30462464e+02,
#          1.40921956e+00, -1.22004251e-05,  4.14348137e+03]])

# %%
reg.intercept_
# Out:
# array([-674.57251188])

# %% [markdown]
# ## Ridge regression

# %%
ridge = linear_model.Ridge(alpha=1)

#using data from mint date only
X1 = masterdf[['time_in_pool_days', 'Mint_Price', 'mint_vol', 'Mint_Volume', 'Mint_PerChange']]
y1 = masterdf[['net_value_vs_holding_percentage']]

# %%
time_train, time_test, gain_train, gain_test = train_test_split(X1,
                                                                y1,
                                                                test_size=0.1,
                                                                random_state=42)

# %%
model1 = ridge.fit(X1, y1)
model1.coef_
# Out:
# array([[-1.42076240e+00, -4.50611560e-01,  3.43308088e+02,
#         -9.20691854e-06,  1.44257852e+03]])

# %%
time_nvh_reg = Ridge()
time_nvh_reg.fit(time_train.astype(float), gain_train)
# Out:
# Ridge()

# %%
predict_nvh = time_nvh_reg.predict(time_test)
mean_squared_error(gain_test, predict_nvh)
# Out:
# 35863697.14841703

# %%
r2_score(gain_test, predict_nvh)
# Out:
# -0.027968286253905683

# %% [markdown]
# ## Lasso regression

# %% [markdown]
# ### Alpha = 0.1

# %%
X = masterdf[['time_in_pool_days', 'eth_rate_mint', 'mint_vol', 'Mint_Price',
       'Mint_Volume', 'Mint_PerChange']] # need to add more features
y = masterdf[['net_value_vs_holding_percentage']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
clf = linear_model.Lasso(alpha=0.1)
clf.fit(X_train, y_train)
# Out:
# /Users/samantha/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 526184518.3889403, tolerance: 106093.35923261124
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=0.1)

# %%
clf.coef_
# Out:
# array([-2.99745748e-01,  6.19426419e-04,  6.09619858e+01, -8.64853996e-02,
#         2.48163629e-05,  8.22122722e+02])

# %%
yhat = clf.predict(X_test)

# %%
mean_squared_error(y_test, yhat)
# Out:
# 19573494.293389086

# %%
r2_score(y_test, yhat)
# Out:
# -0.018835626132981842

# %% [markdown]
# ### Alpha = 1

# %%
clf = linear_model.Lasso(alpha=1)
clf.fit(X_train, y_train)
# Out:
# /Users/samantha/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 526303851.27998006, tolerance: 106093.35923261124
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=1)

# %%
clf.coef_
# Out:
# array([-2.97009038e-01, -2.81798597e-01,  6.23438244e+01,  1.95758804e-01,
#         2.59282994e-05,  7.03590989e+01])

# %%
yhat = clf.predict(X_test)

# %%
mean_squared_error(y_test, yhat)
# Out:
# 19605372.141436443

# %%
r2_score(y_test, yhat)
# Out:
# -0.02049492552982346

# %% [markdown]
# ### Alpha = 10

# %%
clf = linear_model.Lasso(alpha=10)
clf.fit(X_train, y_train)
# Out:
# /Users/samantha/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:530: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 320697892.5916323, tolerance: 106093.35923261124
#   model = cd_fast.enet_coordinate_descent(
# Lasso(alpha=10)

# %%
clf.coef_
# Out:
# array([-2.69514661e-01, -3.23077443e-01,  4.94554071e+01,  2.48335724e-01,
#         2.58638567e-05,  0.00000000e+00])

# %%
yhat = clf.predict(X_test)

# %%
mean_squared_error(y_test, yhat)
# Out:
# 19629601.380117532

# %%
r2_score(y_test, yhat)
# Out:
# -0.021756101035451447

# %% [markdown]
# ## Random Forrest

# %% [markdown]
# ### Random Forrest on Raw Data

# %%
X = masterdf[['time_in_pool_days', 'eth_rate_mint', 'mint_vol', 'Mint_Price','Mint_Volume']] # need to add more features
y = masterdf[['net_value_vs_holding_percentage']]

# %%
masterdf[['net_value_vs_holding_percentage']].describe()
# Out:
#        net_value_vs_holding_percentage
# count                        282.00000
# mean                         319.48504
# std                         2779.39749
# min                          -40.09744
# 25%                            0.00259
# 50%                            0.06510
# 75%                            0.74911
# max                        32452.98773

# %%
# try for 5+ categories, precision recall (false positives + false negatives) - which categories are you better at predicting
# for categories that we are better at predicting, show trends/plots (x vs actual y)
# explore feature importances, then only do exercises for features that are important 
# other models to try: MLP (neural network in scikit learn)
k = 0
for i in range(len(y)):
    if y['net_value_vs_holding_percentage'][i] > 0.749113:
        y.loc[i, 'category'] = 'high'
    elif 0.002593 < y['net_value_vs_holding_percentage'][i] < 0.749113:
        y.loc[i, 'category'] = 'mild'
    elif y['net_value_vs_holding_percentage'][i] < 0.002593:
        y.loc[i, 'category'] = 'low'
# Out:
# /Users/samantha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1599: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = infer_fill_value(value)
# /Users/samantha/opt/anaconda3/lib/python3.8/site-packages/pandas/core/indexing.py:1720: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=0)

# %%
clf = RandomForestClassifier(max_depth=2, random_state=0)
clf.fit(X_train, y_train[['category']])
ypred = clf.predict(X_test)
# Out:
# <ipython-input-924-d9ca5f8b8d89>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_train, y_train[['category']])

# %%
y_actual = y_test['category'].to_list()
k = 0
for i in range(len(ypred)):
    if(ypred[i] == y_actual[i]) : 
        k+=1
print(k/len(ypred))
# Out:
# 0.6705882352941176

# %% [markdown]
# ### Random Forrest on Quartiles

# %%
df['y_q2'] = pd.qcut(df['net_value_vs_holding_percentage'], 6, labels=range(6))

# %%
X = df[['time_q', 'eth_rate_mint', 'eth_rate_burn']]
y = df[['y_q2']]

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

# %%
clf = RandomForestClassifier(max_depth=2, random_state=0)
clf.fit(X_train, y_train)
ypred = clf.predict(X_test)
# Out:
# <ipython-input-929-e1ca3f4b7da1>:2: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_train, y_train)

# %%
clf.feature_importances_
# Out:
# array([0.4116938 , 0.32544679, 0.26285941])

# %%
r2_score(ypred, y_test)
# Out:
# 0.6968963240149681

# %%
mean_squared_error(y_test, ypred)
# Out:
# 1.0588235294117647

# %%
import seaborn as sns
plt.figure(figsize=(5, 7))

ax = sns.distplot(y_test, color="r", label="Actual Value")
sns.distplot(ypred, color="b", label="Fitted Values" , ax=ax, bins=5)
ax.legend(['Actual Value', 'Fitted Values'])
plt.title('Actual vs Fitted Values for Price')
plt.show()
# Out:
# /Users/samantha/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/samantha/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# middle area have low prediction accuracy because overlapping features can be confusing, but in general the model can predict high and low gains </br>

# %%
y_test_value = y_test['y_q2'].values.to_list()

# %%
# percentage of false positive: when we say a higher value for an actual low gain
cnt = 0
for i in range(len(y_test_value)):
    if y_test_value[i] < ypred[i] - 1: # gives a small space for error
        cnt += 1
cnt / len(y_test_value)
# Out:
# 0.0784313725490196

# %%
# percentage of false positive: when we say a higher value for an actual low gain
cnt = 0
for i in range(len(y_test_value)):
    if y_test_value[i] > ypred[i] + 1: # gives a small space for error
        cnt += 1
cnt / len(y_test_value)
# Out:
# 0.058823529411764705

# %%
df['y_q2'] = pd.qcut(df['net_value_vs_holding_percentage'], 6, labels=range(6))

X = df[['time_q', 'eth_rate_mint', 'eth_rate_burn']]
y = df[['y_q2']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=0)

clf = RandomForestClassifier(max_depth=2, random_state=0)
clf.fit(X_train, y_train)
ypred = clf.predict(X_test)

clf.feature_importances_

r2_score(ypred, y_test)

mean_squared_error(y_test, ypred)

import seaborn as sns
plt.figure(figsize=(5, 7))

ax = sns.distplot(y_test, color="r", label="Actual Value")
sns.distplot(ypred, color="b", label="Fitted Values" , ax=ax, bins=5)
ax.legend(['Actual Value', 'Fitted Values'])
plt.title('Actual vs Fitted Values for Price')
plt.show()

# middle area have low prediction accuracy because overlapping features can be confusing, but in general the model can predict high and low gains </br>

y_test_value = y_test['y_q2'].values.to_list()

# percentage of false positive: when we say a higher value for an actual low gain
cnt = 0
for i in range(len(y_test_value)):
    if y_test_value[i] < ypred[i] - 1: # gives a small space for error
        cnt += 1
cnt / len(y_test_value)

# percentage of false positive: when we say a higher value for an actual low gain
cnt = 0
for i in range(len(y_test_value)):
    if y_test_value[i] > ypred[i] + 1: # gives a small space for error
        cnt += 1
cnt / len(y_test_value)
# Out:
# <ipython-input-940-2ad92956b912>:9: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   clf.fit(X_train, y_train)
# /Users/samantha/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/samantha/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# 0.058823529411764705

# %% [markdown]
# ## Extra tests on features

# %%
X = masterdf[['time_in_pool_days', 'eth_rate_mint', 'mint_vol', 'Mint_Price']] # need to add more features
y = masterdf[['net_value_vs_holding_percentage']]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
clf = linear_model.Lasso(alpha=10)
clf.fit(X_train, y_train)
# Out:
# Lasso(alpha=10)

# %%
clf.coef_
# Out:
# array([-0.14580297, -0.12614532, 42.9249535 , -0.099696  ])

# %%
yhat = clf.predict(X_test)

# %%
r2_score(y_test, yhat)
# Out:
# -0.01605358161040793

# %% [markdown]
# # Extraneous Machine Learning

# %% [markdown]
# ## KNN Classification: Classifying Action based on ETH Volume

# %% [markdown]
# newly added usdc / newly added eth

# %%
wallet1_transactions['new_eth_rate'] = \
    wallet1_transactions['newly_added_usdc'] / wallet1_transactions['newly_added_eth']

# %%
# filter out one outlier value
wallet1_transactions_filtered = wallet1_transactions[abs(wallet1_transactions['new_eth_rate'])<1000000]
len(wallet1_transactions_filtered)
# Out:
# 429615

# %%
X = wallet1_transactions_filtered[['new_eth_rate']].to_numpy().reshape(-1,1)
y = wallet1_transactions_filtered['action_name'].to_numpy().reshape(-1,1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=0)

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(X_train, y_train)
# Out:
# /Users/samantha/opt/anaconda3/lib/python3.8/site-packages/sklearn/neighbors/_classification.py:179: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return self._fit(X, y)
# KNeighborsClassifier(n_neighbors=3)

# %%
predictions = knn.predict(X_test)

# %%
def get_unique_values(array):
    array = pd.DataFrame(array)
    array.columns = ['action_name']
    print(array.action_name.unique())

# %%
get_unique_values(predictions)
# Out:
# ['SWAP' 'BURN' 'MINT']

# %%
knn.score(X_test, y_test)
# Out:
# 0.9916909425631114

# %%
# confusion matrix 
cm = confusion_matrix(y_test, predictions)
fig, ax = plt.subplots(1,1)
m = ax.matshow(cm)
fig.colorbar(m)
ax.xaxis.set_label_position('top')
labels = ['BURN', 'MINT', 'SWAP']
ax.set(title = 'Confusion Matrix',
       xticks=np.arange(len(labels)),
       yticks=np.arange(len(labels)),
       xticklabels=labels,
       yticklabels=labels)
plt.tight_layout()

# %% [markdown]
# ## Actual Gain vs. Time Spent in Pool

# %%
time_train, time_test, gain_train, gain_test = train_test_split(oneburnonemint[["time_in_pool_days"]],
                                                                oneburnonemint["actual_gain"],
                                                                test_size=0.1,
                                                                random_state=42)

# %%
time_gain_reg = LinearRegression()
time_gain_reg.fit(time_train, gain_train)
# Out:
# LinearRegression()

# %%
predict_gain = time_gain_reg.predict(time_test)
mean_squared_error(gain_test, predict_gain)
# Out:
# 3992677948.1118956

# %%
r2_score(gain_test, predict_gain)
# Out:
# -1.9631417857008828

# %%
plt.style.use('seaborn-whitegrid')
plt.plot(time_train, gain_train, 'o', color='black')
plt.xlabel('Time Spent in the Pool')
plt.ylabel('Actual Gain')
plt.title("Scatterplot of Time in Pool to Actual USD Gain", fontsize=12)
plt.show()

# %% [markdown]
# ## Actual gain vs. rate change

# %%
rate_train, rate_test, gain_train, gain_test = train_test_split(oneburnonemint[['rate_change']],
                                                                oneburnonemint[['actual_gain']],
                                                                test_size=0.1,
                                                                random_state=42)

# %%
rate_gain_reg = LinearRegression()

# %%
rate_gain_reg.fit(rate_train, gain_train)
# Out:
# LinearRegression()

# %%
predict_gain = rate_gain_reg.predict(rate_test)

# %%
mean_squared_error(gain_test, predict_gain)
# Out:
# 5405548181.887065

# %%
r2_score(gain_test, predict_gain)
# Out:
# -3.0116948826146865

# %%
plt.style.use('seaborn-whitegrid')
plt.plot(rate_train, gain_train, 'o', color='black')
plt.xlabel('Rate Change between Burn and Mint')
plt.ylabel('Actual Gain')
plt.title("Scatterplot of Rate Changes to Actual USD Gain", fontsize=12)
plt.show()
